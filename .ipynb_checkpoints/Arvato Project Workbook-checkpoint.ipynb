# %% [markdown]
# # Capstone Project: Create a Customer Segmentation Report for Arvato Financial Services
#
# In this project, you will analyze demographics data for customers of a mail-order sales company in Germany, comparing it against demographics information for the general population. You'll use unsupervised learning techniques to perform customer segmentation, identifying the parts of the population that best describe the core customer base of the company. Then, you'll apply what you've learned on a third dataset with demographics information for targets of a marketing campaign for the company, and use a model to predict which individuals are most likely to convert into becoming customers for the company. The data that you will use has been provided by our partners at Bertelsmann Arvato Analytics, and represents a real-life data science task.
#
# If you completed the first term of this program, you will be familiar with the first part of this project, from the unsupervised learning project. The versions of those two datasets used in this project will include many more features and has not been pre-cleaned. You are also free to choose whatever approach you'd like to analyzing the data rather than follow pre-determined steps. In your work on this project, make sure that you carefully document your steps and decisions, since your main deliverable for this project will be a blog post reporting your findings.

# %%
# import libraries here; add more as necessary
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pprint
import operator
import time
from sklearn.preprocessing import Imputer
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA    
from sklearn.preprocessing import LabelEncoder
# !pip install mca
import mca
import chardet
# magic word for producing visualizations in notebook
# %matplotlib inline
# Out:
# Requirement already satisfied: mca in /opt/conda/lib/python3.6/site-packages (1.0.3)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.6/site-packages (from mca) (0.19.1)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.6/site-packages (from mca) (0.23.3)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.6/site-packages (from mca) (1.12.1)
# Requirement already satisfied: python-dateutil>=2.5.0 in /opt/conda/lib/python3.6/site-packages (from pandas->mca) (2.6.1)
# Requirement already satisfied: pytz>=2011k in /opt/conda/lib/python3.6/site-packages (from pandas->mca) (2017.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.6/site-packages (from python-dateutil>=2.5.0->pandas->mca) (1.11.0)

# %% [markdown]
# ## Part 0: Get to Know the Data
#
# There are four data files associated with this project:
#
# - `Udacity_AZDIAS_052018.csv`: Demographics data for the general population of Germany; 891 211 persons (rows) x 366 features (columns).
# - `Udacity_CUSTOMERS_052018.csv`: Demographics data for customers of a mail-order company; 191 652 persons (rows) x 369 features (columns).
# - `Udacity_MAILOUT_052018_TRAIN.csv`: Demographics data for individuals who were targets of a marketing campaign; 42 982 persons (rows) x 367 (columns).
# - `Udacity_MAILOUT_052018_TEST.csv`: Demographics data for individuals who were targets of a marketing campaign; 42 833 persons (rows) x 366 (columns).
#
# Each row of the demographics files represents a single person, but also includes information outside of individuals, including information about their household, building, and neighborhood. Use the information from the first two files to figure out how customers ("CUSTOMERS") are similar to or differ from the general population at large ("AZDIAS"), then use your analysis to make predictions on the other two files ("MAILOUT"), predicting which recipients are most likely to become a customer for the mail-order company.
#
# The "CUSTOMERS" file contains three extra columns ('CUSTOMER_GROUP', 'ONLINE_PURCHASE', and 'PRODUCT_GROUP'), which provide broad information about the customers depicted in the file. The original "MAILOUT" file included one additional column, "RESPONSE", which indicated whether or not each recipient became a customer of the company. For the "TRAIN" subset, this column has been retained, but in the "TEST" subset it has been removed; it is against that withheld column that your final predictions will be assessed in the Kaggle competition.
#
# Otherwise, all of the remaining columns are the same between the three data files. For more information about the columns depicted in the files, you can refer to two Excel spreadsheets provided in the workspace. [One of them](./DIAS Information Levels - Attributes 2017.xlsx) is a top-level list of attributes and descriptions, organized by informational category. [The other](./DIAS Attributes - Values 2017.xlsx) is a detailed mapping of data values for each feature in alphabetical order.
#
# In the below cell, we've provided some initial code to load in the first two datasets. Note for all of the `.csv` data files in this project that they're semicolon (`;`) delimited, so an additional argument in the [`read_csv()`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html) call has been included to read in the data properly. Also, considering the size of the datasets, it may take some time for them to load completely.
#
# You'll notice when the data is loaded in that a warning message will immediately pop up. Before you really start digging into the modeling and analysis, you're going to need to perform some cleaning. Take some time to browse the structure of the data and look over the informational spreadsheets to understand the data values. Make some decisions on which features to keep, which features to drop, and if any revisions need to be made on data formats. It'll be a good idea to create a function with pre-processing steps, since you'll need to clean all of the datasets before you work with them.

# %%
# load in the data
azdias = pd.read_csv('../../data/Term2/capstone/arvato_data/Udacity_AZDIAS_052018.csv', sep=';', dtype=str)
customers = pd.read_csv('../../data/Term2/capstone/arvato_data/Udacity_CUSTOMERS_052018.csv', sep=';', dtype=str)

# %%
# Be sure to add in a lot more cells (both markdown and code) to document your
# approach and findings!

# %%
azdias.head()
# Out:
#       LNR AGER_TYP AKT_DAT_KL ALTER_HH ALTER_KIND1 ALTER_KIND2 ALTER_KIND3  \
# 0  910215       -1        NaN      NaN         NaN         NaN         NaN
# 1  910220       -1          9        0         NaN         NaN         NaN
# 2  910225       -1          9       17         NaN         NaN         NaN
# 3  910226        2          1       13         NaN         NaN         NaN
# 4  910241       -1          1       20         NaN         NaN         NaN
#
#   ALTER_KIND4 ALTERSKATEGORIE_FEIN ANZ_HAUSHALTE_AKTIV         ...           \
# 0         NaN                  NaN                 NaN         ...
# 1         NaN                   21                  11         ...
# 2         NaN                   17                  10         ...
# 3         NaN                   13                   1         ...
# 4         NaN                   14                   3         ...
#
#    VHN VK_DHT4A VK_DISTANZ VK_ZG11 W_KEIT_KIND_HH WOHNDAUER_2008 WOHNLAGE  \
# 0  NaN      NaN        NaN     NaN            NaN            NaN      NaN
# 1    4        8         11      10              3              9        4
# 2    2        9          9       6              3              9        2
# 3    0        7         10      11            NaN              9        7
# 4    2        3          5       4              2              9        3
#
#   ZABEOTYP ANREDE_KZ ALTERSKATEGORIE_GROB
# 0        3         1                    2
# 1        5         2                    1
# 2        5         2                    3
# 3        3         2                    4
# 4        4         1                    3
#
# [5 rows x 366 columns]

# %%
azdias["LNR"].nunique()
# Out:
# 891221

# %% [markdown]
# It seems like each row has unique LNR value.

# %%
customers["LNR"].nunique() == customers.shape[0]
# Out:
# True

# %%
np.intersect1d(azdias["LNR"], customers["LNR"])
# Out:
# array([], dtype=object)

# %%
with open("dias.csv.csv", "rb") as dias:
    dias_content = dias.read()
    print(chardet.detect(dias_content))
# Out:
# {'encoding': 'Windows-1252', 'confidence': 0.73, 'language': ''}

# %%
dias = pd.read_csv("dias.csv.csv", encoding="Windows-1252")

# %%
dias.head(20)
# Out:
#                Attribute                                   Description  Value  \
# 0               AGER_TYP                            best-ager typology     -1
# 1                    NaN                                           NaN      0
# 2                    NaN                                           NaN      1
# 3                    NaN                                           NaN      2
# 4                    NaN                                           NaN      3
# 5   ALTERSKATEGORIE_GROB  age classification through prename analysis   -1, 0
# 6                    NaN                                           NaN      1
# 7                    NaN                                           NaN      2
# 8                    NaN                                           NaN      3
# 9                    NaN                                           NaN      4
# 10                   NaN                                           NaN      9
# 11              ALTER_HH                 main age within the household      0
# 12                   NaN                                           NaN      1
# 13                   NaN                                           NaN      2
# 14                   NaN                                           NaN      3
# 15                   NaN                                           NaN      4
# 16                   NaN                                           NaN      5
# 17                   NaN                                           NaN      6
# 18                   NaN                                           NaN      7
# 19                   NaN                                           NaN      8
#
#                              Meaning
# 0                            unknown
# 1         no classification possible
# 2                    passive elderly
# 3                   cultural elderly
# 4          experience-driven elderly
# 5                            unknown
# 6                         < 30 years
# 7                      30 - 45 years
# 8                      46 - 60 years
# 9                         > 60 years
# 10             uniformly distributed
# 11  unknown / no main age detectable
# 12         01.01.1895 bis 31.12.1899
# 13         01.01.1900 bis 31.12.1904
# 14         01.01.1905 bis 31.12.1909
# 15         01.01.1910 bis 31.12.1914
# 16         01.01.1915 bis 31.12.1919
# 17         01.01.1920 bis 31.12.1924
# 18         01.01.1925 bis 31.12.1929
# 19         01.01.1930 bis 31.12.1934

# %%
dias = dias.fillna(method="ffill")

# %%
dias.head(20)
# Out:
#                Attribute                                   Description  Value  \
# 0               AGER_TYP                            best-ager typology     -1
# 1               AGER_TYP                            best-ager typology      0
# 2               AGER_TYP                            best-ager typology      1
# 3               AGER_TYP                            best-ager typology      2
# 4               AGER_TYP                            best-ager typology      3
# 5   ALTERSKATEGORIE_GROB  age classification through prename analysis   -1, 0
# 6   ALTERSKATEGORIE_GROB  age classification through prename analysis       1
# 7   ALTERSKATEGORIE_GROB  age classification through prename analysis       2
# 8   ALTERSKATEGORIE_GROB  age classification through prename analysis       3
# 9   ALTERSKATEGORIE_GROB  age classification through prename analysis       4
# 10  ALTERSKATEGORIE_GROB  age classification through prename analysis       9
# 11              ALTER_HH                 main age within the household      0
# 12              ALTER_HH                 main age within the household      1
# 13              ALTER_HH                 main age within the household      2
# 14              ALTER_HH                 main age within the household      3
# 15              ALTER_HH                 main age within the household      4
# 16              ALTER_HH                 main age within the household      5
# 17              ALTER_HH                 main age within the household      6
# 18              ALTER_HH                 main age within the household      7
# 19              ALTER_HH                 main age within the household      8
#
#                              Meaning
# 0                            unknown
# 1         no classification possible
# 2                    passive elderly
# 3                   cultural elderly
# 4          experience-driven elderly
# 5                            unknown
# 6                         < 30 years
# 7                      30 - 45 years
# 8                      46 - 60 years
# 9                         > 60 years
# 10             uniformly distributed
# 11  unknown / no main age detectable
# 12         01.01.1895 bis 31.12.1899
# 13         01.01.1900 bis 31.12.1904
# 14         01.01.1905 bis 31.12.1909
# 15         01.01.1910 bis 31.12.1914
# 16         01.01.1915 bis 31.12.1919
# 17         01.01.1920 bis 31.12.1924
# 18         01.01.1925 bis 31.12.1929
# 19         01.01.1930 bis 31.12.1934

# %%
attribute_names = dias[["Attribute", "Description"]].drop_duplicates()

# %%
attribute_desc = {}

# %%
for index, row in attribute_names.iterrows():
    attribute_desc[row[0]] = row[1]

# %%
attribute_desc
# Out:
# {'AGER_TYP': 'best-ager typology',
#  'ALTERSKATEGORIE_GROB': 'age classification through prename analysis ',
#  'ALTER_HH': 'main age within the household',
#  'ANREDE_KZ': 'gender',
#  'ANZ_HAUSHALTE_AKTIV': 'number of households in the building',
#  'ANZ_HH_TITEL': 'number of academic title holder in building',
#  'ANZ_PERSONEN': 'number of adult persons in the household',
#  'ANZ_TITEL': 'number of professional title holder in household ',
#  'BALLRAUM': 'distance to next urban centre ',
#  'BIP_FLAG': 'business-flag indicating companies in the building',
#  'CAMEO_DEUG_2015': 'CAMEO classification 2015 - Uppergroup',
#  'CAMEO_DEU_2015': 'CAMEO classification 2015 - detailled classification',
#  'CAMEO_DEUINTL_2015': '(each German CAMEO code belongs to one international code)',
#  'CJT_GESAMTTYP': 'customer journey typology',
#  'D19_BANKEN_ANZ_12': 'transaction activity BANKS in the last 12 months',
#  'D19_BANKEN_ANZ_24': 'transaction activity BANKS in the last 24 months',
#  'D19_BANKEN_DATUM': 'actuality of the last transaction for the segment banks TOTAL',
#  'D19_BANKEN_DIREKT_RZ': ' - on grid level -',
#  'D19_BANKEN_GROSS_RZ': ' - on grid level -',
#  'D19_BANKEN_LOKAL_RZ': ' - on grid level -',
#  'D19_BANKEN_OFFLINE_DATUM': 'actuality of the last transaction for the segment banks OFFLINE',
#  'D19_BANKEN_ONLINE_DATUM': 'actuality of the last transaction for the segment banks ONLINE',
#  'D19_BANKEN_ONLINE_QUOTE_12': 'amount of online transactions within all transactions in the segment bank ',
#  'D19_BANKEN_REST_RZ': ' - on grid level -',
#  'D19_BEKLEIDUNG_GEH_RZ': ' - on grid level -',
#  'D19_BEKLEIDUNG_REST_RZ': ' - on grid level -',
#  'D19_BILDUNG_RZ': ' - on grid level -',
#  'D19_BIO_OEKO_RZ': ' - on grid level -',
#  'D19_BUCH_RZ': ' - on grid level -',
#  'D19_DIGIT_SERV_RZ': ' - on grid level -',
#  'D19_DROGERIEARTIKEL_RZ': ' - on grid level -',
#  'D19_ENERGIE_RZ': ' - on grid level -',
#  'D19_FREIZEIT_RZ': ' - on grid level -',
#  'D19_GARTEN_RZ': ' - on grid level -',
#  'D19_GESAMT_ANZ_12': 'transaction activity TOTAL POOL in the last 12 months ',
#  'D19_GESAMT_ANZ_24': 'transaction activity TOTAL POOL in the last 24 months ',
#  'D19_GESAMT_DATUM': 'actuality of the last transaction with the complete file TOTAL',
#  'D19_GESAMT_OFFLINE_DATUM': 'actuality of the last transaction with the complete file OFFLINE',
#  'D19_GESAMT_ONLINE_DATUM': 'actuality of the last transaction with the complete file ONLINE',
#  'D19_GESAMT_ONLINE_QUOTE_12': 'amount of online transactions within all transactions in the complete file ',
#  'D19_HANDWERK_RZ': ' - on grid level -',
#  'D19_HAUS_DEKO_RZ': ' - on grid level -',
#  'D19_KINDERARTIKEL_RZ': ' - on grid level -',
#  'D19_KONSUMTYP': 'consumption type ',
#  'D19_KK_KUNDENTYP': 'consumption movement in the last 12 months',
#  'D19_KOSMETIK_RZ': ' - on grid level -',
#  'D19_LEBENSMITTEL_RZ': ' - on grid level -',
#  'D19_LOTTO_RZ': ' - on grid level -',
#  'D19_NAHRUNGSERGAENZUNG_RZ': ' - on grid level -',
#  'D19_RATGEBER_RZ': ' - on grid level -',
#  'D19_REISEN_RZ': ' - on grid level -',
#  'D19_SAMMELARTIKEL_RZ': ' - on grid level -',
#  'D19_SCHUHE_RZ': ' - on grid level -',
#  'D19_SONSTIGE_RZ': ' - on grid level -',
#  'D19_TECHNIK_RZ': ' - on grid level -',
#  'D19_TELKO_ANZ_12': 'transaction activity TELCO in the last 12 months',
#  'D19_TELKO_ANZ_24': 'transaction activity TELCO in the last 24 months',
#  'D19_TELKO_DATUM': 'actuality of the last transaction for the segment telecommunication TOTAL',
#  'D19_TELKO_MOBILE_RZ': ' - on grid level -',
#  'D19_TELKO_OFFLINE_DATUM': 'actuality of the last transaction for the segment telecommunication OFFLINE',
#  'D19_TELKO_ONLINE_DATUM': 'actuality of the last transaction for the segment telecommunication ONLINE',
#  'D19_TELKO_REST_RZ': ' - on grid level -',
#  'D19_TIERARTIKEL_RZ': ' - on grid level -',
#  'D19_VERSAND_ANZ_12': 'transaction activity MAIL-ORDER in the last 12 months',
#  'D19_VERSAND_ANZ_24': 'transaction activity MAIL-ORDER in the last 24 months',
#  'D19_VERSAND_DATUM': 'actuality of the last transaction for the segment mail-order TOTAL',
#  'D19_VERSAND_OFFLINE_DATUM': 'actuality of the last transaction for the segment mail-order OFFLINE',
#  'D19_VERSAND_ONLINE_DATUM': 'actuality of the last transaction for the segment mail-order ONLINE',
#  'D19_VERSAND_ONLINE_QUOTE_12': 'amount of online transactions within all transactions in the segment mail-order ',
#  'D19_VERSAND_REST_RZ': ' - on grid level -',
#  'D19_VERSICHERUNGEN_RZ': ' - on grid level -',
#  'D19_VERSI_ANZ_12': 'transaction activity INSURANCE in the last 12 months',
#  'D19_VERSI_ANZ_24': 'transaction activity INSURANCE in the last 24 months',
#  'D19_VOLLSORTIMENT_RZ': ' - on grid level -',
#  'D19_WEIN_FEINKOST_RZ': ' - on grid level -',
#  'EWDICHTE': 'density of inhabitants per square kilometer',
#  'FINANZTYP': 'best descirbing financial type for the person',
#  'FINANZ_ANLEGER': 'financial typology: investor',
#  'FINANZ_HAUSBAUER': 'financial typology: main focus is the own house',
#  'FINANZ_MINIMALIST': 'financial typology: low financial interest',
#  'FINANZ_SPARER': 'financial typology: money saver',
#  'FINANZ_UNAUFFAELLIGER': 'financial typology: unremarkable',
#  'FINANZ_VORSORGER': 'financial typology: be prepared',
#  'GEBAEUDETYP': 'type of building (residential or commercial)',
#  'GEBAEUDETYP_RASTER': 'industrial areas',
#  'GEBURTSJAHR': 'year of birth',
#  'GFK_URLAUBERTYP': 'vacation habits',
#  'GEOSCORE_KLS7': 'microgeographical risk index concerning population solvency',
#  'GREEN_AVANTGARDE': 'the environmental sustainability is the dominating movement in the youth of these consumers',
#  'HAUSHALTSSTRUKTUR': 'structure of the household (single-hh, couple with different surnames, family,...)',
#  'HEALTH_TYP': 'health typology',
#  'HH_EINKOMMEN_SCORE': 'estimated household net income ',
#  'INNENSTADT': 'distance to the city centre',
#  'KBA05_ALTER1': 'share of car owners less than 31 years old',
#  'KBA05_ALTER2': 'share of car owners inbetween 31 and 45 years of age',
#  'KBA05_ALTER3': 'share of car owners inbetween 45 and 60 years of age',
#  'KBA05_ALTER4': 'share of cars owners elder than 61 years',
#  'KBA05_ANHANG': 'share of trailers in the microcell',
#  'KBA05_ANTG1': 'number of 1-2 family houses in the cell',
#  'KBA05_ANTG2': 'number of 3-5 family houses in the cell',
#  'KBA05_ANTG3': 'number of 6-10 family houses in the cell',
#  'KBA05_ANTG4': 'number of >10 family houses in the cell',
#  'KBA05_AUTOQUOT': 'share of cars per household',
#  'KBA05_BAUMAX': 'most common building-type within the cell',
#  'KBA05_CCM1': 'share of cars with less than 1399ccm',
#  'KBA05_CCM2': 'share of cars with 1400ccm to 1799 ccm',
#  'KBA05_CCM3': 'share of cars with 1800ccm to 2499 ccm',
#  'KBA05_CCM4': 'share of cars with more than 2499ccm',
#  'KBA05_DIESEL': 'share of cars with Diesel-engine in the microcell',
#  'KBA05_FRAU': 'share of female car owners',
#  'KBA05_GBZ': 'number of buildings in the microcell',
#  'KBA05_HERST1': 'share of top German manufacturer (Mercedes, BMW) ',
#  'KBA05_HERST2': 'share of Volkswagen-Cars (including Audi)',
#  'KBA05_HERST3': 'share of Ford/Opel',
#  'KBA05_HERST4': 'share of European manufacturer (e.g. Fiat, Peugeot, Rover,...)',
#  'KBA05_HERST5': 'share of asian manufacturer (e.g. Toyota, Kia,...)',
#  'KBA05_HERSTTEMP': 'development of the most common car manufacturers in the neighbourhood',
#  'KBA05_KRSAQUOT': 'share of cars per household (reffered to county average)',
#  'KBA05_KRSHERST1': 'share of Mercedes/BMW (reffered to the county average)',
#  'KBA05_KRSHERST2': 'share of Volkswagen (reffered to the county average)',
#  'KBA05_KRSHERST3': 'share of Ford/Opel (reffered to the county average)',
#  'KBA05_KRSKLEIN': 'share of small cars (referred to the county average)',
#  'KBA05_KRSOBER': 'share of upper class cars (referred to the county average)',
#  'KBA05_KRSVAN': 'share of vans (referred to the county average)',
#  'KBA05_KRSZUL': 'share of newbuilt cars (referred to the county average)',
#  'KBA05_KW1': 'share of cars with less than 59 KW engine power',
#  'KBA05_KW2': 'share of cars with an engine power between 60 and 119 KW',
#  'KBA05_KW3': 'share of cars with an engine power of more than 119 KW',
#  'KBA05_MAXAH': 'most common age of car owners in the microcell',
#  'KBA05_MAXBJ': 'most common age of the cars in the microcell',
#  'KBA05_MAXHERST': 'most common car manufacturer in the microcell',
#  'KBA05_MAXSEG': 'most common car segment in the microcell',
#  'KBA05_MAXVORB': 'most common preowner structure in the microcell',
#  'KBA05_MOD1': 'share of upper class cars (in an AZ specific definition)',
#  'KBA05_MOD2': 'share of middle class cars (in an AZ specific definition)',
#  'KBA05_MOD3': 'share of Golf-class cars (in an AZ specific definition)',
#  'KBA05_MOD4': 'share of small cars (in an AZ specific definition)',
#  'KBA05_MOD8': 'share of vans (in an AZ specific definition)',
#  'KBA05_MODTEMP': 'development of the most common car segment in the neighbourhood',
#  'KBA05_MOTOR': 'most common engine size in the microcell',
#  'KBA05_MOTRAD': 'share of motorcycles per household',
#  'KBA05_SEG1': 'share of very small cars (Ford Ka etc.) in the microcell',
#  'KBA05_SEG10': 'share of more specific cars (Vans, convertables, all-terrains, MUVs etc.)',
#  'KBA05_SEG2': 'share of small and very small cars (Ford Fiesta, Ford Ka etc.) in the microcell',
#  'KBA05_SEG3': 'share of lowe midclass cars (Ford Focus etc.) in the microcell',
#  'KBA05_SEG4': 'share of middle class cars (Ford Mondeo etc.) in the microcell',
#  'KBA05_SEG5': 'share of upper middle class cars and upper class cars (BMW5er, BMW7er etc.)',
#  'KBA05_SEG6': 'share of upper class cars (BMW 7er etc.) in the microcell',
#  'KBA05_SEG7': 'share of all-terrain vehicles and MUVs in the microcell',
#  'KBA05_SEG8': 'share of roadster and convertables in the microcell',
#  'KBA05_SEG9': 'share of vans in the microcell',
#  'KBA05_VORB0': 'share of cars with no preowner',
#  'KBA05_VORB1': 'share of cars with one or two preowner',
#  'KBA05_VORB2': 'share of cars with more than two preowner',
#  'KBA05_ZUL1': 'share of cars built before 1994',
#  'KBA05_ZUL2': 'share of cars built between 1994 and 2000',
#  'KBA05_ZUL3': 'share of cars built between 2001 and 2002',
#  'KBA05_ZUL4': 'share of cars built from 2003 on',
#  'KBA13_ALTERHALTER_30': 'share of car owners below 31 within the PLZ8',
#  'KBA13_ALTERHALTER_45': 'share of car owners between 31 and 45 within the PLZ8',
#  'KBA13_ALTERHALTER_60': 'share of car owners between 46 and 60 within the PLZ8',
#  'KBA13_ALTERHALTER_61': 'share of car owners elder than 61 within the PLZ8',
#  'KBA13_ANZAHL_PKW': 'number of cars in the PLZ8',
#  'KBA13_AUDI': 'share of AUDI within the PLZ8',
#  'KBA13_AUTOQUOTE': 'share of cars per household within the PLZ8',
#  'KBA13_BJ_1999': 'share of cars built between 1995 and 1999 within the PLZ8',
#  'KBA13_BJ_2000': 'share of cars built between 2000 and 2003 within the PLZ8',
#  'KBA13_BJ_2004': 'share of cars built before 2004 within the PLZ8',
#  'KBA13_BJ_2006': 'share of cars built between 2005 and 2006 within the PLZ8',
#  'KBA13_BJ_2008': 'share of cars built in 2008 within the PLZ8',
#  'KBA13_BJ_2009': 'share of cars built in 2009 within the PLZ8',
#  'KBA13_BMW': 'share of BMW within the PLZ8',
#  'KBA13_CCM_1000': 'share of cars with less than 1000ccm within the PLZ8',
#  'KBA13_CCM_1200': 'share of cars with 1000ccm to 1199ccm within the PLZ8',
#  'KBA13_CCM_1400': 'share of cars with 1200ccm to 1399ccm within the PLZ8',
#  'KBA13_CCM_0_1400': 'share of cars with less than 1400ccm within the PLZ8',
#  'KBA13_CCM_1500': 'share of cars with 1400ccm to 1499ccm within the PLZ8',
#  'KBA13_CCM_1400_2500': 'share of cars with 1400ccm to 2499ccm within the PLZ8',
#  'KBA13_CCM_1600': 'share of cars with 1500ccm to 1599ccm within the PLZ8',
#  'KBA13_CCM_1800': 'share of cars with 1600ccm to 1799ccm within the PLZ8',
#  'KBA13_CCM_2000': 'share of cars with 1800ccm to 1999ccm within the PLZ8',
#  'KBA13_CCM_2500': 'share of cars with 2000ccm to 2499ccm within the PLZ8',
#  'KBA13_CCM_2501': 'share of cars with more than 2500ccm within the PLZ8',
#  'KBA13_CCM_3000': 'share of cars with 2500ccm to 2999ccm within the PLZ8',
#  'KBA13_CCM_3001': 'share of cars with more than 3000ccm within the PLZ8',
#  'KBA13_FAB_ASIEN': 'share of other Asian Manufacturers within the PLZ8',
#  'KBA13_FAB_SONSTIGE': 'share of other Manufacturers within the PLZ8',
#  'KBA13_FIAT': 'share of FIAT within the PLZ8',
#  'KBA13_FORD': 'share of FORD within the PLZ8',
#  'KBA13_HALTER_20': 'share of car owners below 21 within the PLZ8',
#  'KBA13_HALTER_25': 'share of car owners between 21 and 25 within the PLZ8',
#  'KBA13_HALTER_30': 'share of car owners between 26 and 30 within the PLZ8',
#  'KBA13_HALTER_35': 'share of car owners between 31 and 35 within the PLZ8',
#  'KBA13_HALTER_40': 'share of car owners between 36 and 40 within the PLZ8',
#  'KBA13_HALTER_45': 'share of car owners between 41 and 45 within the PLZ8',
#  'KBA13_HALTER_50': 'share of car owners between 46 and 50 within the PLZ8',
#  'KBA13_HALTER_55': 'share of car owners between 51 and 55 within the PLZ8',
#  'KBA13_HALTER_60': 'share of car owners between 56 and 60 within the PLZ8',
#  'KBA13_HALTER_65': 'share of car owners between 61 and 65 within the PLZ8',
#  'KBA13_HALTER_66': 'share of car owners over 66 within the PLZ8',
#  'KBA13_HERST_ASIEN': 'share of Asian Manufacturers within the PLZ8',
#  'KBA13_HERST_AUDI_VW': 'share of Volkswagen & Audi within the PLZ8',
#  'KBA13_HERST_BMW_BENZ': 'share of BMW & Mercedes Benz within the PLZ8',
#  'KBA13_HERST_EUROPA': 'share of European cars within the PLZ8',
#  'KBA13_HERST_FORD_OPEL': 'share of Ford & Opel/Vauxhall within the PLZ8',
#  'KBA13_HERST_SONST': 'share of other cars within the PLZ8',
#  'KBA13_KMH_110': 'share of cars with max speed 110 km/h within the PLZ8',
#  'KBA13_KMH_140': 'share of cars with max speed between 110 km/h and 140km/h within the PLZ8',
#  'KBA13_KMH_180': 'share of cars with max speed between 110 km/h and 180km/h within the PLZ8',
#  'KBA13_KMH_0_140': 'share of cars with max speed 140 km/h within the PLZ8',
#  'KBA13_KMH_140_210': 'share of cars with max speed between 140 and 210 km/h within the PLZ8',
#  'KBA13_KMH_211': 'share of cars with a greater max speed than 210 km/h within the PLZ8',
#  'KBA13_KMH_250': 'share of cars with max speed between 210 and 250 km/h within the PLZ8',
#  'KBA13_KMH_251': 'share of cars with a greater max speed than 250 km/h within the PLZ8',
#  'KBA13_KRSAQUOT': 'share of cars per household (referred to the county average) - PLZ8',
#  'KBA13_KRSHERST_AUDI_VW': 'share of Volkswagen (referred to the county average) - PLZ8',
#  'KBA13_KRSHERST_BMW_BENZ': 'share of BMW/Mercedes Benz (referred to the county average) - PLZ8',
#  'KBA13_KRSHERST_FORD_OPEL': 'share of FORD/Opel (referred to the county average) - PLZ8',
#  'KBA13_KRSSEG_KLEIN': 'share of small cars (referred to the county average) - PLZ8',
#  'KBA13_KRSSEG_OBER': 'share of upper class cars (referred to the county average) - PLZ8',
#  'KBA13_KRSSEG_VAN': 'share of vans (referred to the county average) - PLZ8',
#  'KBA13_KRSZUL_NEU': 'share of newbuilt cars (referred to the county average) - PLZ8',
#  'KBA13_KW_30': 'share of cars up to 30 KW engine power - PLZ8',
#  'KBA13_KW_40': 'share of cars with an engine power between 31 and 40 KW - PLZ8',
#  'KBA13_KW_50': 'share of cars with an engine power between 41 and 50 KW - PLZ8',
#  'KBA13_KW_60': 'share of cars with an engine power between 51 and 60 KW - PLZ8',
#  'KBA13_KW_0_60': 'share of cars up to 60 KW engine power - PLZ8',
#  'KBA13_KW_70': 'share of cars with an engine power between 61 and 70 KW - PLZ8',
#  'KBA13_KW_61_120': 'share of cars with an engine power between 61 and 120 KW - PLZ8',
#  'KBA13_KW_80': 'share of cars with an engine power between 71 and 80 KW - PLZ8',
#  'KBA13_KW_90': 'share of cars with an engine power between 81 and 90 KW - PLZ8',
#  'KBA13_KW_110': 'share of cars with an engine power between 91 and 110 KW - PLZ8',
#  'KBA13_KW_120': 'share of cars with an engine power between 111 and 120 KW - PLZ8',
#  'KBA13_KW_121': 'share of cars with an engine power more than 120 KW - PLZ8',
#  'KBA13_MAZDA': 'share of MAZDA within the PLZ8',
#  'KBA13_MERCEDES': 'share of MERCEDES within the PLZ8',
#  'KBA13_MOTOR': 'most common motor size within the PLZ8',
#  'KBA13_NISSAN': 'share of NISSAN within the PLZ8',
#  'KBA13_OPEL': 'share of OPEL within the PLZ8',
#  'KBA13_PEUGEOT': 'share of PEUGEOT within the PLZ8',
#  'KBA13_RENAULT': 'share of RENAULT within the PLZ8',
#  'KBA13_SEG_GELAENDEWAGEN': 'share of allterrain within the PLZ8',
#  'KBA13_SEG_GROSSRAUMVANS': 'share of big sized vans within the PLZ8',
#  'KBA13_SEG_KLEINST': 'share of very small cars (Ford Ka etc.) in the PLZ8',
#  'KBA13_SEG_KLEINWAGEN': 'share of small and very small cars (Ford Fiesta, Ford Ka etc.) in the PLZ8',
#  'KBA13_SEG_KOMPAKTKLASSE': 'share of lowe midclass cars (Ford Focus etc.) in the PLZ8',
#  'KBA13_SEG_MINIVANS': 'share of minivans within the PLZ8',
#  'KBA13_SEG_MINIWAGEN': 'share of minicars within the PLZ8',
#  'KBA13_SEG_MITTELKLASSE': 'share of middle class cars (Ford Mondeo etc.) in the PLZ8',
#  'KBA13_SEG_OBEREMITTELKLASSE': 'share of upper middle class cars and upper class cars (BMW5er, BMW7er etc.)',
#  'KBA13_SEG_OBERKLASSE': 'share of upper class cars (BMW 7er etc.) in the PLZ8',
#  'KBA13_SEG_SONSTIGE': 'share of other cars within the PLZ8',
#  'KBA13_SEG_SPORTWAGEN': 'share of sportscars within the PLZ8',
#  'KBA13_SEG_UTILITIES': 'share of MUVs/SUVs within the PLZ8',
#  'KBA13_SEG_VAN': 'share of vans within the PLZ8',
#  'KBA13_SEG_WOHNMOBILE': 'share of roadmobiles within the PLZ8',
#  'KBA13_SITZE_4': 'number of cars with less than 5 seats in the PLZ8',
#  'KBA13_SITZE_5': 'number of cars with 5 seats in the PLZ8',
#  'KBA13_SITZE_6': 'number of cars with more than 5 seats in the PLZ8',
#  'KBA13_TOYOTA': 'share of TOYOTA within the PLZ8',
#  'KBA13_VORB_0': 'share of cars with no preowner - PLZ8',
#  'KBA13_VORB_1': 'share of cars with 1 preowner - PLZ8',
#  'KBA13_VORB_1_2': 'share of cars with 1 or 2 preowner - PLZ8',
#  'KBA13_VORB_2': 'share of cars with 2 preowner - PLZ8',
#  'KBA13_VORB_3': 'share of cars with 3 or more preowner - PLZ8',
#  'KBA13_VW': 'share of VOLKSWAGEN within the PLZ8',
#  'KKK': 'purchasing power',
#  'KONSUMNAEHE': 'distance from a building to PoS (Point of Sale)',
#  'LP_FAMILIE_FEIN': 'familytyp fine',
#  'LP_FAMILIE_GROB': 'familytyp rough',
#  'LP_LEBENSPHASE_FEIN': 'lifestage fine ',
#  'LP_LEBENSPHASE_GROB': 'lifestage rough',
#  'LP_STATUS_FEIN': 'social status fine',
#  'LP_STATUS_GROB': 'social status rough',
#  'MIN_GEBAEUDEJAHR': 'year the building was first mentioned in our database',
#  'MOBI_REGIO': 'moving patterns',
#  'NATIONALITAET_KZ': 'nationaltity (scored by prename analysis)',
#  'ONLINE_AFFINITAET': 'online affinity',
#  'ORTSGR_KLS9': "'- classified number of inhabitants",
#  'OST_WEST_KZ': 'flag indicating the former GDR/FRG',
#  'PLZ8_ANTG1': 'number of 1-2 family houses in the PLZ8',
#  'PLZ8_ANTG2': 'number of 3-5 family houses in the PLZ8',
#  'PLZ8_ANTG3': 'number of 6-10 family houses in the PLZ8',
#  'PLZ8_ANTG4': 'number of >10 family houses in the PLZ8',
#  'PLZ8_BAUMAX': 'most common building-type within the PLZ8',
#  'PLZ8_GBZ': 'number of buildings within the PLZ8',
#  'PLZ8_HHZ': 'number of households within the PLZ8',
#  'PRAEGENDE_JUGENDJAHRE': "dominating movement in the person's youth (avantgarde or mainstream)",
#  'REGIOTYP': 'neighbourhood ',
#  'RELAT_AB': 'share of unemployed in relation to the county the community belongs to',
#  'RETOURTYP_BK_S': 'return type',
#  'SEMIO_DOM': 'affinity indicating in what way the person is dominant minded',
#  'SEMIO_ERL': 'affinity indicating in what way the person is eventful orientated',
#  'SEMIO_FAM': 'affinity indicating in what way the person is familiar minded',
#  'SEMIO_KAEM': 'affinity indicating in what way the person is of a fightfull attitude',
#  'SEMIO_KRIT': 'affinity indicating in what way the person is critical minded',
#  'SEMIO_KULT': 'affinity indicating in what way the person is cultural minded',
#  'SEMIO_LUST': 'affinity indicating in what way the person is sensual minded',
#  'SEMIO_MAT': 'affinity indicating in what way the person is material minded',
#  'SEMIO_PFLICHT': 'affinity indicating in what way the person is dutyfull traditional minded',
#  'SEMIO_RAT': 'affinity indicating in what way the person is of a rational mind',
#  'SEMIO_REL': 'affinity indicating in what way the person is religious',
#  'SEMIO_SOZ': 'affinity indicating in what way the person is social minded',
#  'SEMIO_TRADV': 'affinity indicating in what way the person is traditional minded',
#  'SEMIO_VERT': 'affinity indicating in what way the person is dreamily',
#  'SHOPPER_TYP': 'shopping typology',
#  'SOHO_FLAG': 'small office/home office flag',
#  'TITEL_KZ': 'flag whether this person holds an academic title',
#  'VERS_TYP': 'insurance typology ',
#  'WOHNDAUER_2008': 'length of residence',
#  'WOHNLAGE': 'residential-area ',
#  'WACHSTUMSGEBIET_NB': 'growing area (population growth in the last 5 years)',
#  'W_KEIT_KIND_HH': 'likelihood of a child present in this household',
#  'ZABEOTYP': 'typification of energy consumers'}

# %%
azdias_clean = azdias.rename(columns=attribute_desc)

# %%
customers_clean = customers.rename(columns=attribute_desc)

# %%
azdias_clean.columns
# Out:
# Index(['LNR', 'best-ager typology', 'AKT_DAT_KL',
#        'main age within the household', 'ALTER_KIND1', 'ALTER_KIND2',
#        'ALTER_KIND3', 'ALTER_KIND4', 'ALTERSKATEGORIE_FEIN',
#        'number of households in the building',
#        ...
#        'VHN', 'VK_DHT4A', 'VK_DISTANZ', 'VK_ZG11',
#        'likelihood of a child present in this household',
#        'length of residence', 'residential-area ',
#        'typification of energy consumers', 'gender',
#        'age classification through prename analysis '],
#       dtype='object', length=366)

# %%
customers_clean.columns
# Out:
# Index(['LNR', 'best-ager typology', 'AKT_DAT_KL',
#        'main age within the household', 'ALTER_KIND1', 'ALTER_KIND2',
#        'ALTER_KIND3', 'ALTER_KIND4', 'ALTERSKATEGORIE_FEIN',
#        'number of households in the building',
#        ...
#        'VK_ZG11', 'likelihood of a child present in this household',
#        'length of residence', 'residential-area ',
#        'typification of energy consumers', 'PRODUCT_GROUP', 'CUSTOMER_GROUP',
#        'ONLINE_PURCHASE', 'gender',
#        'age classification through prename analysis '],
#       dtype='object', length=369)

# %%
customers_clean.CUSTOMER_GROUP.head()
# Out:
# 0     MULTI_BUYER
# 1    SINGLE_BUYER
# 2     MULTI_BUYER
# 3     MULTI_BUYER
# 4     MULTI_BUYER
# Name: CUSTOMER_GROUP, dtype: object

# %%
customers_clean.ONLINE_PURCHASE.value_counts()
# Out:
# 0    174356
# 1     17296
# Name: ONLINE_PURCHASE, dtype: int64

# %%
customers_clean.PRODUCT_GROUP.unique()
# Out:
# array(['COSMETIC_AND_FOOD', 'FOOD', 'COSMETIC'], dtype=object)

# %%
list(customers_clean.columns)
# Out:
# ['LNR',
#  'best-ager typology',
#  'AKT_DAT_KL',
#  'main age within the household',
#  'ALTER_KIND1',
#  'ALTER_KIND2',
#  'ALTER_KIND3',
#  'ALTER_KIND4',
#  'ALTERSKATEGORIE_FEIN',
#  'number of households in the building',
#  'number of academic title holder in building',
#  'ANZ_KINDER',
#  'number of adult persons in the household',
#  'ANZ_STATISTISCHE_HAUSHALTE',
#  'number of professional title holder in household ',
#  'ARBEIT',
#  'distance to next urban centre ',
#  'CAMEO classification 2015 - detailled classification',
#  'CAMEO classification 2015 - Uppergroup',
#  'CAMEO_INTL_2015',
#  'customer journey typology',
#  'CJT_KATALOGNUTZER',
#  'CJT_TYP_1',
#  'CJT_TYP_2',
#  'CJT_TYP_3',
#  'CJT_TYP_4',
#  'CJT_TYP_5',
#  'CJT_TYP_6',
#  'transaction activity BANKS in the last 12 months',
#  'transaction activity BANKS in the last 24 months',
#  'actuality of the last transaction for the segment banks TOTAL',
#  'D19_BANKEN_DIREKT',
#  'D19_BANKEN_GROSS',
#  'D19_BANKEN_LOKAL',
#  'actuality of the last transaction for the segment banks OFFLINE',
#  'actuality of the last transaction for the segment banks ONLINE',
#  'amount of online transactions within all transactions in the segment bank ',
#  'D19_BANKEN_REST',
#  'D19_BEKLEIDUNG_GEH',
#  'D19_BEKLEIDUNG_REST',
#  'D19_BILDUNG',
#  'D19_BIO_OEKO',
#  'D19_BUCH_CD',
#  'D19_DIGIT_SERV',
#  'D19_DROGERIEARTIKEL',
#  'D19_ENERGIE',
#  'D19_FREIZEIT',
#  'D19_GARTEN',
#  'transaction activity TOTAL POOL in the last 12 months ',
#  'transaction activity TOTAL POOL in the last 24 months ',
#  'actuality of the last transaction with the complete file TOTAL',
#  'actuality of the last transaction with the complete file OFFLINE',
#  'actuality of the last transaction with the complete file ONLINE',
#  'amount of online transactions within all transactions in the complete file ',
#  'D19_HANDWERK',
#  'D19_HAUS_DEKO',
#  'D19_KINDERARTIKEL',
#  'consumption type ',
#  'D19_KONSUMTYP_MAX',
#  'D19_KOSMETIK',
#  'D19_LEBENSMITTEL',
#  'D19_LETZTER_KAUF_BRANCHE',
#  'D19_LOTTO',
#  'D19_NAHRUNGSERGAENZUNG',
#  'D19_RATGEBER',
#  'D19_REISEN',
#  'D19_SAMMELARTIKEL',
#  'D19_SCHUHE',
#  'D19_SONSTIGE',
#  'D19_SOZIALES',
#  'D19_TECHNIK',
#  'transaction activity TELCO in the last 12 months',
#  'transaction activity TELCO in the last 24 months',
#  'actuality of the last transaction for the segment telecommunication TOTAL',
#  'D19_TELKO_MOBILE',
#  'actuality of the last transaction for the segment telecommunication OFFLINE',
#  'actuality of the last transaction for the segment telecommunication ONLINE',
#  'D19_TELKO_ONLINE_QUOTE_12',
#  'D19_TELKO_REST',
#  'D19_TIERARTIKEL',
#  'transaction activity MAIL-ORDER in the last 12 months',
#  'transaction activity MAIL-ORDER in the last 24 months',
#  'actuality of the last transaction for the segment mail-order TOTAL',
#  'actuality of the last transaction for the segment mail-order OFFLINE',
#  'actuality of the last transaction for the segment mail-order ONLINE',
#  'amount of online transactions within all transactions in the segment mail-order ',
#  'D19_VERSAND_REST',
#  'transaction activity INSURANCE in the last 12 months',
#  'transaction activity INSURANCE in the last 24 months',
#  'D19_VERSI_DATUM',
#  'D19_VERSI_OFFLINE_DATUM',
#  'D19_VERSI_ONLINE_DATUM',
#  'D19_VERSI_ONLINE_QUOTE_12',
#  'D19_VERSICHERUNGEN',
#  'D19_VOLLSORTIMENT',
#  'D19_WEIN_FEINKOST',
#  'DSL_FLAG',
#  'EINGEFUEGT_AM',
#  'EINGEZOGENAM_HH_JAHR',
#  'density of inhabitants per square kilometer',
#  'EXTSEL992',
#  'financial typology: investor',
#  'financial typology: main focus is the own house',
#  'financial typology: low financial interest',
#  'financial typology: money saver',
#  'financial typology: unremarkable',
#  'financial typology: be prepared',
#  'best descirbing financial type for the person',
#  'FIRMENDICHTE',
#  'type of building (residential or commercial)',
#  'industrial areas',
#  'year of birth',
#  'GEMEINDETYP',
#  'vacation habits',
#  'the environmental sustainability is the dominating movement in the youth of these consumers',
#  'health typology',
#  'HH_DELTA_FLAG',
#  'estimated household net income ',
#  'distance to the city centre',
#  'share of car owners less than 31 years old',
#  'share of car owners inbetween 31 and 45 years of age',
#  'share of car owners inbetween 45 and 60 years of age',
#  'share of cars owners elder than 61 years',
#  'share of trailers in the microcell',
#  'number of 1-2 family houses in the cell',
#  'number of 3-5 family houses in the cell',
#  'number of 6-10 family houses in the cell',
#  'number of >10 family houses in the cell',
#  'share of cars per household',
#  'most common building-type within the cell',
#  'share of cars with less than 1399ccm',
#  'share of cars with 1400ccm to 1799 ccm',
#  'share of cars with 1800ccm to 2499 ccm',
#  'share of cars with more than 2499ccm',
#  'share of cars with Diesel-engine in the microcell',
#  'share of female car owners',
#  'number of buildings in the microcell',
#  'share of top German manufacturer (Mercedes, BMW) ',
#  'share of Volkswagen-Cars (including Audi)',
#  'share of Ford/Opel',
#  'share of European manufacturer (e.g. Fiat, Peugeot, Rover,...)',
#  'share of asian manufacturer (e.g. Toyota, Kia,...)',
#  'development of the most common car manufacturers in the neighbourhood',
#  'share of cars per household (reffered to county average)',
#  'share of Mercedes/BMW (reffered to the county average)',
#  'share of Volkswagen (reffered to the county average)',
#  'share of Ford/Opel (reffered to the county average)',
#  'share of small cars (referred to the county average)',
#  'share of upper class cars (referred to the county average)',
#  'share of vans (referred to the county average)',
#  'share of newbuilt cars (referred to the county average)',
#  'share of cars with less than 59 KW engine power',
#  'share of cars with an engine power between 60 and 119 KW',
#  'share of cars with an engine power of more than 119 KW',
#  'most common age of car owners in the microcell',
#  'most common age of the cars in the microcell',
#  'most common car manufacturer in the microcell',
#  'most common car segment in the microcell',
#  'most common preowner structure in the microcell',
#  'share of upper class cars (in an AZ specific definition)',
#  'share of middle class cars (in an AZ specific definition)',
#  'share of Golf-class cars (in an AZ specific definition)',
#  'share of small cars (in an AZ specific definition)',
#  'share of vans (in an AZ specific definition)',
#  'development of the most common car segment in the neighbourhood',
#  'most common engine size in the microcell',
#  'share of motorcycles per household',
#  'share of very small cars (Ford Ka etc.) in the microcell',
#  'share of more specific cars (Vans, convertables, all-terrains, MUVs etc.)',
#  'share of small and very small cars (Ford Fiesta, Ford Ka etc.) in the microcell',
#  'share of lowe midclass cars (Ford Focus etc.) in the microcell',
#  'share of middle class cars (Ford Mondeo etc.) in the microcell',
#  'share of upper middle class cars and upper class cars (BMW5er, BMW7er etc.)',
#  'share of upper class cars (BMW 7er etc.) in the microcell',
#  'share of all-terrain vehicles and MUVs in the microcell',
#  'share of roadster and convertables in the microcell',
#  'share of vans in the microcell',
#  'share of cars with no preowner',
#  'share of cars with one or two preowner',
#  'share of cars with more than two preowner',
#  'share of cars built before 1994',
#  'share of cars built between 1994 and 2000',
#  'share of cars built between 2001 and 2002',
#  'share of cars built from 2003 on',
#  'share of car owners below 31 within the PLZ8',
#  'share of car owners between 31 and 45 within the PLZ8',
#  'share of car owners between 46 and 60 within the PLZ8',
#  'share of car owners elder than 61 within the PLZ8',
#  'KBA13_ANTG1',
#  'KBA13_ANTG2',
#  'KBA13_ANTG3',
#  'KBA13_ANTG4',
#  'number of cars in the PLZ8',
#  'share of AUDI within the PLZ8',
#  'share of cars per household within the PLZ8',
#  'KBA13_BAUMAX',
#  'share of cars built between 1995 and 1999 within the PLZ8',
#  'share of cars built between 2000 and 2003 within the PLZ8',
#  'share of cars built before 2004 within the PLZ8',
#  'share of cars built between 2005 and 2006 within the PLZ8',
#  'share of cars built in 2008 within the PLZ8',
#  'share of cars built in 2009 within the PLZ8',
#  'share of BMW within the PLZ8',
#  'share of cars with less than 1400ccm within the PLZ8',
#  'share of cars with less than 1000ccm within the PLZ8',
#  'share of cars with 1000ccm to 1199ccm within the PLZ8',
#  'share of cars with 1200ccm to 1399ccm within the PLZ8',
#  'KBA13_CCM_1401_2500',
#  'share of cars with 1400ccm to 1499ccm within the PLZ8',
#  'share of cars with 1500ccm to 1599ccm within the PLZ8',
#  'share of cars with 1600ccm to 1799ccm within the PLZ8',
#  'share of cars with 1800ccm to 1999ccm within the PLZ8',
#  'share of cars with 2000ccm to 2499ccm within the PLZ8',
#  'share of cars with more than 2500ccm within the PLZ8',
#  'share of cars with 2500ccm to 2999ccm within the PLZ8',
#  'share of cars with more than 3000ccm within the PLZ8',
#  'share of other Asian Manufacturers within the PLZ8',
#  'share of other Manufacturers within the PLZ8',
#  'share of FIAT within the PLZ8',
#  'share of FORD within the PLZ8',
#  'KBA13_GBZ',
#  'share of car owners below 21 within the PLZ8',
#  'share of car owners between 21 and 25 within the PLZ8',
#  'share of car owners between 26 and 30 within the PLZ8',
#  'share of car owners between 31 and 35 within the PLZ8',
#  'share of car owners between 36 and 40 within the PLZ8',
#  'share of car owners between 41 and 45 within the PLZ8',
#  'share of car owners between 46 and 50 within the PLZ8',
#  'share of car owners between 51 and 55 within the PLZ8',
#  'share of car owners between 56 and 60 within the PLZ8',
#  'share of car owners between 61 and 65 within the PLZ8',
#  'share of car owners over 66 within the PLZ8',
#  'share of Asian Manufacturers within the PLZ8',
#  'share of Volkswagen & Audi within the PLZ8',
#  'share of BMW & Mercedes Benz within the PLZ8',
#  'share of European cars within the PLZ8',
#  'share of Ford & Opel/Vauxhall within the PLZ8',
#  'share of other cars within the PLZ8',
#  'KBA13_HHZ',
#  'share of cars with max speed 140 km/h within the PLZ8',
#  'share of cars with max speed 110 km/h within the PLZ8',
#  'share of cars with max speed between 110 km/h and 140km/h within the PLZ8',
#  'share of cars with max speed between 140 and 210 km/h within the PLZ8',
#  'share of cars with max speed between 110 km/h and 180km/h within the PLZ8',
#  'KBA13_KMH_210',
#  'share of cars with a greater max speed than 210 km/h within the PLZ8',
#  'share of cars with max speed between 210 and 250 km/h within the PLZ8',
#  'share of cars with a greater max speed than 250 km/h within the PLZ8',
#  'share of cars per household (referred to the county average) - PLZ8',
#  'share of Volkswagen (referred to the county average) - PLZ8',
#  'share of BMW/Mercedes Benz (referred to the county average) - PLZ8',
#  'share of FORD/Opel (referred to the county average) - PLZ8',
#  'share of small cars (referred to the county average) - PLZ8',
#  'share of upper class cars (referred to the county average) - PLZ8',
#  'share of vans (referred to the county average) - PLZ8',
#  'share of newbuilt cars (referred to the county average) - PLZ8',
#  'share of cars up to 60 KW engine power - PLZ8',
#  'share of cars with an engine power between 91 and 110 KW - PLZ8',
#  'share of cars with an engine power between 111 and 120 KW - PLZ8',
#  'share of cars with an engine power more than 120 KW - PLZ8',
#  'share of cars up to 30 KW engine power - PLZ8',
#  'share of cars with an engine power between 31 and 40 KW - PLZ8',
#  'share of cars with an engine power between 41 and 50 KW - PLZ8',
#  'share of cars with an engine power between 51 and 60 KW - PLZ8',
#  'share of cars with an engine power between 61 and 120 KW - PLZ8',
#  'share of cars with an engine power between 61 and 70 KW - PLZ8',
#  'share of cars with an engine power between 71 and 80 KW - PLZ8',
#  'share of cars with an engine power between 81 and 90 KW - PLZ8',
#  'share of MAZDA within the PLZ8',
#  'share of MERCEDES within the PLZ8',
#  'most common motor size within the PLZ8',
#  'share of NISSAN within the PLZ8',
#  'share of OPEL within the PLZ8',
#  'share of PEUGEOT within the PLZ8',
#  'share of RENAULT within the PLZ8',
#  'share of allterrain within the PLZ8',
#  'share of big sized vans within the PLZ8',
#  'share of very small cars (Ford Ka etc.) in the PLZ8',
#  'share of small and very small cars (Ford Fiesta, Ford Ka etc.) in the PLZ8',
#  'share of lowe midclass cars (Ford Focus etc.) in the PLZ8',
#  'share of minivans within the PLZ8',
#  'share of minicars within the PLZ8',
#  'share of middle class cars (Ford Mondeo etc.) in the PLZ8',
#  'share of upper middle class cars and upper class cars (BMW5er, BMW7er etc.)',
#  'share of upper class cars (BMW 7er etc.) in the PLZ8',
#  'share of other cars within the PLZ8',
#  'share of sportscars within the PLZ8',
#  'share of MUVs/SUVs within the PLZ8',
#  'share of vans within the PLZ8',
#  'share of roadmobiles within the PLZ8',
#  'number of cars with less than 5 seats in the PLZ8',
#  'number of cars with 5 seats in the PLZ8',
#  'number of cars with more than 5 seats in the PLZ8',
#  'share of TOYOTA within the PLZ8',
#  'share of cars with no preowner - PLZ8',
#  'share of cars with 1 preowner - PLZ8',
#  'share of cars with 1 or 2 preowner - PLZ8',
#  'share of cars with 2 preowner - PLZ8',
#  'share of cars with 3 or more preowner - PLZ8',
#  'share of VOLKSWAGEN within the PLZ8',
#  'KK_KUNDENTYP',
#  'purchasing power',
#  'KOMBIALTER',
#  'distance from a building to PoS (Point of Sale)',
#  'KONSUMZELLE',
#  'familytyp fine',
#  'familytyp rough',
#  'lifestage fine ',
#  'lifestage rough',
#  'social status fine',
#  'social status rough',
#  'year the building was first mentioned in our database',
#  'MOBI_RASTER',
#  'moving patterns',
#  'nationaltity (scored by prename analysis)',
#  'online affinity',
#  "'- classified number of inhabitants",
#  'flag indicating the former GDR/FRG',
#  'number of 1-2 family houses in the PLZ8',
#  'number of 3-5 family houses in the PLZ8',
#  'number of 6-10 family houses in the PLZ8',
#  'number of >10 family houses in the PLZ8',
#  'most common building-type within the PLZ8',
#  'number of buildings within the PLZ8',
#  'number of households within the PLZ8',
#  "dominating movement in the person's youth (avantgarde or mainstream)",
#  'neighbourhood ',
#  'share of unemployed in relation to the county the community belongs to',
#  'return type',
#  'RT_KEIN_ANREIZ',
#  'RT_SCHNAEPPCHEN',
#  'RT_UEBERGROESSE',
#  'affinity indicating in what way the person is dominant minded',
#  'affinity indicating in what way the person is eventful orientated',
#  'affinity indicating in what way the person is familiar minded',
#  'affinity indicating in what way the person is of a fightfull attitude',
#  'affinity indicating in what way the person is critical minded',
#  'affinity indicating in what way the person is cultural minded',
#  'affinity indicating in what way the person is sensual minded',
#  'affinity indicating in what way the person is material minded',
#  'affinity indicating in what way the person is dutyfull traditional minded',
#  'affinity indicating in what way the person is of a rational mind',
#  'affinity indicating in what way the person is religious',
#  'affinity indicating in what way the person is social minded',
#  'affinity indicating in what way the person is traditional minded',
#  'affinity indicating in what way the person is dreamily',
#  'shopping typology',
#  'SOHO_KZ',
#  'STRUKTURTYP',
#  'flag whether this person holds an academic title',
#  'UMFELD_ALT',
#  'UMFELD_JUNG',
#  'UNGLEICHENN_FLAG',
#  'VERDICHTUNGSRAUM',
#  'insurance typology ',
#  'VHA',
#  'VHN',
#  'VK_DHT4A',
#  'VK_DISTANZ',
#  'VK_ZG11',
#  'likelihood of a child present in this household',
#  'length of residence',
#  'residential-area ',
#  'typification of energy consumers',
#  'PRODUCT_GROUP',
#  'CUSTOMER_GROUP',
#  'ONLINE_PURCHASE',
#  'gender',
#  'age classification through prename analysis ']

# %%
dias.head(1)
# Out:
#   Attribute         Description Value  Meaning
# 0  AGER_TYP  best-ager typology    -1  unknown

# %%
customers_clean = customers_clean_backup.copy()

# %%
# for index, row in dias.iterrows():
#     attr, desc, value, meaning = row
#     if desc in list(customers_clean.columns):        
#         customers_clean.loc[customers_clean[desc] == value, desc] = meaning

# %%
customers_clean = pd.get_dummies(customers_clean.iloc[:, 1:], dummy_na=True)

# %%
list(customers_clean.columns)
# Out:
# ['best-ager typology_-1',
#  'best-ager typology_0',
#  'best-ager typology_1',
#  'best-ager typology_2',
#  'best-ager typology_3',
#  'best-ager typology_nan',
#  'AKT_DAT_KL_1',
#  'AKT_DAT_KL_2',
#  'AKT_DAT_KL_3',
#  'AKT_DAT_KL_4',
#  'AKT_DAT_KL_5',
#  'AKT_DAT_KL_6',
#  'AKT_DAT_KL_7',
#  'AKT_DAT_KL_8',
#  'AKT_DAT_KL_9',
#  'AKT_DAT_KL_nan',
#  'main age within the household_0',
#  'main age within the household_10',
#  'main age within the household_11',
#  'main age within the household_12',
#  'main age within the household_13',
#  'main age within the household_14',
#  'main age within the household_15',
#  'main age within the household_16',
#  'main age within the household_17',
#  'main age within the household_18',
#  'main age within the household_19',
#  'main age within the household_2',
#  'main age within the household_20',
#  'main age within the household_21',
#  'main age within the household_3',
#  'main age within the household_4',
#  'main age within the household_5',
#  'main age within the household_6',
#  'main age within the household_7',
#  'main age within the household_8',
#  'main age within the household_9',
#  'main age within the household_nan',
#  'ALTER_KIND1_10',
#  'ALTER_KIND1_11',
#  'ALTER_KIND1_12',
#  'ALTER_KIND1_13',
#  'ALTER_KIND1_14',
#  'ALTER_KIND1_15',
#  'ALTER_KIND1_16',
#  'ALTER_KIND1_17',
#  'ALTER_KIND1_18',
#  'ALTER_KIND1_2',
#  'ALTER_KIND1_3',
#  'ALTER_KIND1_4',
#  'ALTER_KIND1_5',
#  'ALTER_KIND1_6',
#  'ALTER_KIND1_7',
#  'ALTER_KIND1_8',
#  'ALTER_KIND1_9',
#  'ALTER_KIND1_nan',
#  'ALTER_KIND2_10',
#  'ALTER_KIND2_11',
#  'ALTER_KIND2_12',
#  'ALTER_KIND2_13',
#  'ALTER_KIND2_14',
#  'ALTER_KIND2_15',
#  'ALTER_KIND2_16',
#  'ALTER_KIND2_17',
#  'ALTER_KIND2_18',
#  'ALTER_KIND2_2',
#  'ALTER_KIND2_3',
#  'ALTER_KIND2_4',
#  'ALTER_KIND2_5',
#  'ALTER_KIND2_6',
#  'ALTER_KIND2_7',
#  'ALTER_KIND2_8',
#  'ALTER_KIND2_9',
#  'ALTER_KIND2_nan',
#  'ALTER_KIND3_10',
#  'ALTER_KIND3_11',
#  'ALTER_KIND3_12',
#  'ALTER_KIND3_13',
#  'ALTER_KIND3_14',
#  'ALTER_KIND3_15',
#  'ALTER_KIND3_16',
#  'ALTER_KIND3_17',
#  'ALTER_KIND3_18',
#  'ALTER_KIND3_5',
#  'ALTER_KIND3_6',
#  'ALTER_KIND3_7',
#  'ALTER_KIND3_8',
#  'ALTER_KIND3_9',
#  'ALTER_KIND3_nan',
#  'ALTER_KIND4_10',
#  'ALTER_KIND4_11',
#  'ALTER_KIND4_12',
#  'ALTER_KIND4_13',
#  'ALTER_KIND4_14',
#  'ALTER_KIND4_15',
#  'ALTER_KIND4_16',
#  'ALTER_KIND4_17',
#  'ALTER_KIND4_18',
#  'ALTER_KIND4_8',
#  'ALTER_KIND4_nan',
#  'ALTERSKATEGORIE_FEIN_0',
#  'ALTERSKATEGORIE_FEIN_10',
#  'ALTERSKATEGORIE_FEIN_11',
#  'ALTERSKATEGORIE_FEIN_12',
#  'ALTERSKATEGORIE_FEIN_13',
#  'ALTERSKATEGORIE_FEIN_14',
#  'ALTERSKATEGORIE_FEIN_15',
#  'ALTERSKATEGORIE_FEIN_16',
#  'ALTERSKATEGORIE_FEIN_17',
#  'ALTERSKATEGORIE_FEIN_18',
#  'ALTERSKATEGORIE_FEIN_19',
#  'ALTERSKATEGORIE_FEIN_2',
#  'ALTERSKATEGORIE_FEIN_20',
#  'ALTERSKATEGORIE_FEIN_21',
#  'ALTERSKATEGORIE_FEIN_22',
#  'ALTERSKATEGORIE_FEIN_23',
#  'ALTERSKATEGORIE_FEIN_24',
#  'ALTERSKATEGORIE_FEIN_25',
#  'ALTERSKATEGORIE_FEIN_3',
#  'ALTERSKATEGORIE_FEIN_4',
#  'ALTERSKATEGORIE_FEIN_5',
#  'ALTERSKATEGORIE_FEIN_6',
#  'ALTERSKATEGORIE_FEIN_7',
#  'ALTERSKATEGORIE_FEIN_8',
#  'ALTERSKATEGORIE_FEIN_9',
#  'ALTERSKATEGORIE_FEIN_nan',
#  'number of households in the building_0',
#  'number of households in the building_1',
#  'number of households in the building_10',
#  'number of households in the building_100',
#  'number of households in the building_101',
#  'number of households in the building_102',
#  'number of households in the building_103',
#  'number of households in the building_104',
#  'number of households in the building_105',
#  'number of households in the building_106',
#  'number of households in the building_107',
#  'number of households in the building_108',
#  'number of households in the building_109',
#  'number of households in the building_11',
#  'number of households in the building_110',
#  'number of households in the building_111',
#  'number of households in the building_112',
#  'number of households in the building_113',
#  'number of households in the building_114',
#  'number of households in the building_115',
#  'number of households in the building_116',
#  'number of households in the building_117',
#  'number of households in the building_118',
#  'number of households in the building_119',
#  'number of households in the building_12',
#  'number of households in the building_120',
#  'number of households in the building_121',
#  'number of households in the building_122',
#  'number of households in the building_123',
#  'number of households in the building_124',
#  'number of households in the building_125',
#  'number of households in the building_126',
#  'number of households in the building_127',
#  'number of households in the building_128',
#  'number of households in the building_129',
#  'number of households in the building_13',
#  'number of households in the building_131',
#  'number of households in the building_133',
#  'number of households in the building_134',
#  'number of households in the building_135',
#  'number of households in the building_136',
#  'number of households in the building_137',
#  'number of households in the building_138',
#  'number of households in the building_139',
#  'number of households in the building_14',
#  'number of households in the building_140',
#  'number of households in the building_141',
#  'number of households in the building_142',
#  'number of households in the building_143',
#  'number of households in the building_145',
#  'number of households in the building_146',
#  'number of households in the building_147',
#  'number of households in the building_148',
#  'number of households in the building_149',
#  'number of households in the building_15',
#  'number of households in the building_150',
#  'number of households in the building_153',
#  'number of households in the building_154',
#  'number of households in the building_155',
#  'number of households in the building_156',
#  'number of households in the building_157',
#  'number of households in the building_158',
#  'number of households in the building_159',
#  'number of households in the building_16',
#  'number of households in the building_160',
#  'number of households in the building_161',
#  'number of households in the building_163',
#  'number of households in the building_165',
#  'number of households in the building_167',
#  'number of households in the building_17',
#  'number of households in the building_170',
#  'number of households in the building_171',
#  'number of households in the building_172',
#  'number of households in the building_178',
#  'number of households in the building_179',
#  'number of households in the building_18',
#  'number of households in the building_181',
#  'number of households in the building_185',
#  'number of households in the building_186',
#  'number of households in the building_189',
#  'number of households in the building_19',
#  'number of households in the building_190',
#  'number of households in the building_195',
#  'number of households in the building_196',
#  'number of households in the building_199',
#  'number of households in the building_2',
#  'number of households in the building_20',
#  'number of households in the building_200',
#  'number of households in the building_202',
#  'number of households in the building_204',
#  'number of households in the building_207',
#  'number of households in the building_209',
#  'number of households in the building_21',
#  'number of households in the building_210',
#  'number of households in the building_211',
#  'number of households in the building_219',
#  'number of households in the building_22',
#  'number of households in the building_221',
#  'number of households in the building_222',
#  'number of households in the building_223',
#  'number of households in the building_229',
#  'number of households in the building_23',
#  'number of households in the building_230',
#  'number of households in the building_238',
#  'number of households in the building_24',
#  'number of households in the building_240',
#  'number of households in the building_243',
#  'number of households in the building_246',
#  'number of households in the building_25',
#  'number of households in the building_252',
#  'number of households in the building_253',
#  'number of households in the building_254',
#  'number of households in the building_258',
#  'number of households in the building_259',
#  'number of households in the building_26',
#  'number of households in the building_265',
#  'number of households in the building_267',
#  'number of households in the building_27',
#  'number of households in the building_274',
#  'number of households in the building_276',
#  'number of households in the building_277',
#  'number of households in the building_28',
#  'number of households in the building_286',
#  'number of households in the building_29',
#  'number of households in the building_290',
#  'number of households in the building_3',
#  'number of households in the building_30',
#  'number of households in the building_301',
#  'number of households in the building_304',
#  'number of households in the building_305',
#  'number of households in the building_307',
#  'number of households in the building_31',
#  'number of households in the building_311',
#  'number of households in the building_32',
#  'number of households in the building_321',
#  'number of households in the building_33',
#  'number of households in the building_331',
#  'number of households in the building_34',
#  'number of households in the building_344',
#  'number of households in the building_348',
#  'number of households in the building_35',
#  'number of households in the building_36',
#  'number of households in the building_366',
#  'number of households in the building_367',
#  'number of households in the building_37',
#  'number of households in the building_379',
#  'number of households in the building_38',
#  'number of households in the building_39',
#  'number of households in the building_395',
#  'number of households in the building_4',
#  'number of households in the building_40',
#  'number of households in the building_41',
#  'number of households in the building_42',
#  'number of households in the building_43',
#  'number of households in the building_44',
#  'number of households in the building_45',
#  'number of households in the building_46',
#  'number of households in the building_47',
#  'number of households in the building_48',
#  'number of households in the building_49',
#  'number of households in the building_5',
#  'number of households in the building_50',
#  'number of households in the building_51',
#  'number of households in the building_52',
#  'number of households in the building_523',
#  'number of households in the building_53',
#  'number of households in the building_54',
#  'number of households in the building_55',
#  'number of households in the building_56',
#  'number of households in the building_57',
#  'number of households in the building_58',
#  'number of households in the building_59',
#  'number of households in the building_6',
#  'number of households in the building_60',
#  'number of households in the building_61',
#  'number of households in the building_62',
#  'number of households in the building_63',
#  'number of households in the building_64',
#  'number of households in the building_65',
#  'number of households in the building_66',
#  'number of households in the building_67',
#  'number of households in the building_68',
#  'number of households in the building_69',
#  'number of households in the building_7',
#  'number of households in the building_70',
#  'number of households in the building_71',
#  'number of households in the building_72',
#  'number of households in the building_73',
#  'number of households in the building_74',
#  'number of households in the building_75',
#  'number of households in the building_76',
#  'number of households in the building_77',
#  'number of households in the building_78',
#  'number of households in the building_79',
#  'number of households in the building_8',
#  'number of households in the building_80',
#  'number of households in the building_81',
#  'number of households in the building_82',
#  'number of households in the building_83',
#  'number of households in the building_84',
#  'number of households in the building_85',
#  'number of households in the building_86',
#  'number of households in the building_87',
#  'number of households in the building_88',
#  'number of households in the building_89',
#  'number of households in the building_9',
#  'number of households in the building_90',
#  'number of households in the building_91',
#  'number of households in the building_92',
#  'number of households in the building_93',
#  'number of households in the building_94',
#  'number of households in the building_95',
#  'number of households in the building_96',
#  'number of households in the building_97',
#  'number of households in the building_98',
#  'number of households in the building_99',
#  'number of households in the building_nan',
#  'number of academic title holder in building_0',
#  'number of academic title holder in building_1',
#  'number of academic title holder in building_10',
#  'number of academic title holder in building_11',
#  'number of academic title holder in building_12',
#  'number of academic title holder in building_13',
#  'number of academic title holder in building_14',
#  'number of academic title holder in building_15',
#  'number of academic title holder in building_17',
#  'number of academic title holder in building_18',
#  'number of academic title holder in building_2',
#  'number of academic title holder in building_20',
#  'number of academic title holder in building_23',
#  'number of academic title holder in building_3',
#  'number of academic title holder in building_4',
#  'number of academic title holder in building_5',
#  'number of academic title holder in building_6',
#  'number of academic title holder in building_7',
#  'number of academic title holder in building_8',
#  'number of academic title holder in building_9',
#  'number of academic title holder in building_nan',
#  'ANZ_KINDER_0',
#  'ANZ_KINDER_1',
#  'ANZ_KINDER_2',
#  'ANZ_KINDER_3',
#  'ANZ_KINDER_4',
#  'ANZ_KINDER_5',
#  'ANZ_KINDER_6',
#  'ANZ_KINDER_7',
#  'ANZ_KINDER_8',
#  'ANZ_KINDER_nan',
#  'number of adult persons in the household_0',
#  'number of adult persons in the household_1',
#  'number of adult persons in the household_10',
#  'number of adult persons in the household_11',
#  'number of adult persons in the household_12',
#  'number of adult persons in the household_13',
#  'number of adult persons in the household_14',
#  'number of adult persons in the household_15',
#  'number of adult persons in the household_16',
#  'number of adult persons in the household_2',
#  'number of adult persons in the household_21',
#  'number of adult persons in the household_3',
#  'number of adult persons in the household_4',
#  'number of adult persons in the household_5',
#  'number of adult persons in the household_6',
#  'number of adult persons in the household_7',
#  'number of adult persons in the household_8',
#  'number of adult persons in the household_9',
#  'number of adult persons in the household_nan',
#  'ANZ_STATISTISCHE_HAUSHALTE_0',
#  'ANZ_STATISTISCHE_HAUSHALTE_1',
#  'ANZ_STATISTISCHE_HAUSHALTE_10',
#  'ANZ_STATISTISCHE_HAUSHALTE_100',
#  'ANZ_STATISTISCHE_HAUSHALTE_101',
#  'ANZ_STATISTISCHE_HAUSHALTE_102',
#  'ANZ_STATISTISCHE_HAUSHALTE_103',
#  'ANZ_STATISTISCHE_HAUSHALTE_104',
#  'ANZ_STATISTISCHE_HAUSHALTE_105',
#  'ANZ_STATISTISCHE_HAUSHALTE_106',
#  'ANZ_STATISTISCHE_HAUSHALTE_107',
#  'ANZ_STATISTISCHE_HAUSHALTE_108',
#  'ANZ_STATISTISCHE_HAUSHALTE_109',
#  'ANZ_STATISTISCHE_HAUSHALTE_11',
#  'ANZ_STATISTISCHE_HAUSHALTE_110',
#  'ANZ_STATISTISCHE_HAUSHALTE_111',
#  'ANZ_STATISTISCHE_HAUSHALTE_112',
#  'ANZ_STATISTISCHE_HAUSHALTE_113',
#  'ANZ_STATISTISCHE_HAUSHALTE_114',
#  'ANZ_STATISTISCHE_HAUSHALTE_115',
#  'ANZ_STATISTISCHE_HAUSHALTE_116',
#  'ANZ_STATISTISCHE_HAUSHALTE_117',
#  'ANZ_STATISTISCHE_HAUSHALTE_118',
#  'ANZ_STATISTISCHE_HAUSHALTE_119',
#  'ANZ_STATISTISCHE_HAUSHALTE_12',
#  'ANZ_STATISTISCHE_HAUSHALTE_120',
#  'ANZ_STATISTISCHE_HAUSHALTE_122',
#  'ANZ_STATISTISCHE_HAUSHALTE_123',
#  'ANZ_STATISTISCHE_HAUSHALTE_124',
#  'ANZ_STATISTISCHE_HAUSHALTE_125',
#  'ANZ_STATISTISCHE_HAUSHALTE_126',
#  'ANZ_STATISTISCHE_HAUSHALTE_127',
#  'ANZ_STATISTISCHE_HAUSHALTE_128',
#  'ANZ_STATISTISCHE_HAUSHALTE_129',
#  'ANZ_STATISTISCHE_HAUSHALTE_13',
#  'ANZ_STATISTISCHE_HAUSHALTE_130',
#  'ANZ_STATISTISCHE_HAUSHALTE_131',
#  'ANZ_STATISTISCHE_HAUSHALTE_132',
#  'ANZ_STATISTISCHE_HAUSHALTE_134',
#  'ANZ_STATISTISCHE_HAUSHALTE_135',
#  'ANZ_STATISTISCHE_HAUSHALTE_136',
#  'ANZ_STATISTISCHE_HAUSHALTE_137',
#  'ANZ_STATISTISCHE_HAUSHALTE_14',
#  'ANZ_STATISTISCHE_HAUSHALTE_140',
#  'ANZ_STATISTISCHE_HAUSHALTE_141',
#  'ANZ_STATISTISCHE_HAUSHALTE_142',
#  'ANZ_STATISTISCHE_HAUSHALTE_143',
#  'ANZ_STATISTISCHE_HAUSHALTE_144',
#  'ANZ_STATISTISCHE_HAUSHALTE_145',
#  'ANZ_STATISTISCHE_HAUSHALTE_146',
#  'ANZ_STATISTISCHE_HAUSHALTE_147',
#  'ANZ_STATISTISCHE_HAUSHALTE_149',
#  'ANZ_STATISTISCHE_HAUSHALTE_15',
#  'ANZ_STATISTISCHE_HAUSHALTE_150',
#  'ANZ_STATISTISCHE_HAUSHALTE_152',
#  'ANZ_STATISTISCHE_HAUSHALTE_153',
#  'ANZ_STATISTISCHE_HAUSHALTE_155',
#  'ANZ_STATISTISCHE_HAUSHALTE_156',
#  'ANZ_STATISTISCHE_HAUSHALTE_158',
#  'ANZ_STATISTISCHE_HAUSHALTE_159',
#  'ANZ_STATISTISCHE_HAUSHALTE_16',
#  'ANZ_STATISTISCHE_HAUSHALTE_160',
#  'ANZ_STATISTISCHE_HAUSHALTE_161',
#  'ANZ_STATISTISCHE_HAUSHALTE_163',
#  'ANZ_STATISTISCHE_HAUSHALTE_167',
#  'ANZ_STATISTISCHE_HAUSHALTE_168',
#  'ANZ_STATISTISCHE_HAUSHALTE_17',
#  'ANZ_STATISTISCHE_HAUSHALTE_170',
#  'ANZ_STATISTISCHE_HAUSHALTE_172',
#  'ANZ_STATISTISCHE_HAUSHALTE_174',
#  'ANZ_STATISTISCHE_HAUSHALTE_178',
#  'ANZ_STATISTISCHE_HAUSHALTE_179',
#  'ANZ_STATISTISCHE_HAUSHALTE_18',
#  'ANZ_STATISTISCHE_HAUSHALTE_180',
#  'ANZ_STATISTISCHE_HAUSHALTE_181',
#  'ANZ_STATISTISCHE_HAUSHALTE_183',
#  'ANZ_STATISTISCHE_HAUSHALTE_184',
#  'ANZ_STATISTISCHE_HAUSHALTE_186',
#  'ANZ_STATISTISCHE_HAUSHALTE_187',
#  'ANZ_STATISTISCHE_HAUSHALTE_189',
#  'ANZ_STATISTISCHE_HAUSHALTE_19',
#  'ANZ_STATISTISCHE_HAUSHALTE_192',
#  'ANZ_STATISTISCHE_HAUSHALTE_193',
#  'ANZ_STATISTISCHE_HAUSHALTE_195',
#  'ANZ_STATISTISCHE_HAUSHALTE_199',
#  'ANZ_STATISTISCHE_HAUSHALTE_2',
#  'ANZ_STATISTISCHE_HAUSHALTE_20',
#  'ANZ_STATISTISCHE_HAUSHALTE_200',
#  'ANZ_STATISTISCHE_HAUSHALTE_201',
#  'ANZ_STATISTISCHE_HAUSHALTE_202',
#  'ANZ_STATISTISCHE_HAUSHALTE_209',
#  'ANZ_STATISTISCHE_HAUSHALTE_21',
#  'ANZ_STATISTISCHE_HAUSHALTE_212',
#  'ANZ_STATISTISCHE_HAUSHALTE_213',
#  'ANZ_STATISTISCHE_HAUSHALTE_218',
#  'ANZ_STATISTISCHE_HAUSHALTE_22',
#  'ANZ_STATISTISCHE_HAUSHALTE_222',
#  'ANZ_STATISTISCHE_HAUSHALTE_223',
#  'ANZ_STATISTISCHE_HAUSHALTE_225',
#  'ANZ_STATISTISCHE_HAUSHALTE_228',
#  'ANZ_STATISTISCHE_HAUSHALTE_23',
#  'ANZ_STATISTISCHE_HAUSHALTE_230',
#  'ANZ_STATISTISCHE_HAUSHALTE_233',
#  'ANZ_STATISTISCHE_HAUSHALTE_235',
#  'ANZ_STATISTISCHE_HAUSHALTE_239',
#  'ANZ_STATISTISCHE_HAUSHALTE_24',
#  'ANZ_STATISTISCHE_HAUSHALTE_240',
#  'ANZ_STATISTISCHE_HAUSHALTE_248',
#  'ANZ_STATISTISCHE_HAUSHALTE_25',
#  'ANZ_STATISTISCHE_HAUSHALTE_251',
#  'ANZ_STATISTISCHE_HAUSHALTE_252',
#  'ANZ_STATISTISCHE_HAUSHALTE_253',
#  'ANZ_STATISTISCHE_HAUSHALTE_256',
#  'ANZ_STATISTISCHE_HAUSHALTE_258',
#  'ANZ_STATISTISCHE_HAUSHALTE_26',
#  'ANZ_STATISTISCHE_HAUSHALTE_268',
#  'ANZ_STATISTISCHE_HAUSHALTE_269',
#  'ANZ_STATISTISCHE_HAUSHALTE_27',
#  'ANZ_STATISTISCHE_HAUSHALTE_274',
#  'ANZ_STATISTISCHE_HAUSHALTE_28',
#  'ANZ_STATISTISCHE_HAUSHALTE_284',
#  'ANZ_STATISTISCHE_HAUSHALTE_289',
#  'ANZ_STATISTISCHE_HAUSHALTE_29',
#  'ANZ_STATISTISCHE_HAUSHALTE_292',
#  'ANZ_STATISTISCHE_HAUSHALTE_296',
#  'ANZ_STATISTISCHE_HAUSHALTE_297',
#  'ANZ_STATISTISCHE_HAUSHALTE_299',
#  'ANZ_STATISTISCHE_HAUSHALTE_3',
#  'ANZ_STATISTISCHE_HAUSHALTE_30',
#  'ANZ_STATISTISCHE_HAUSHALTE_304',
#  'ANZ_STATISTISCHE_HAUSHALTE_309',
#  'ANZ_STATISTISCHE_HAUSHALTE_31',
#  'ANZ_STATISTISCHE_HAUSHALTE_314',
#  'ANZ_STATISTISCHE_HAUSHALTE_317',
#  'ANZ_STATISTISCHE_HAUSHALTE_32',
#  'ANZ_STATISTISCHE_HAUSHALTE_322',
#  'ANZ_STATISTISCHE_HAUSHALTE_33',
#  'ANZ_STATISTISCHE_HAUSHALTE_339',
#  'ANZ_STATISTISCHE_HAUSHALTE_34',
#  'ANZ_STATISTISCHE_HAUSHALTE_35',
#  'ANZ_STATISTISCHE_HAUSHALTE_354',
#  'ANZ_STATISTISCHE_HAUSHALTE_36',
#  'ANZ_STATISTISCHE_HAUSHALTE_365',
#  'ANZ_STATISTISCHE_HAUSHALTE_37',
#  'ANZ_STATISTISCHE_HAUSHALTE_371',
#  'ANZ_STATISTISCHE_HAUSHALTE_375',
#  'ANZ_STATISTISCHE_HAUSHALTE_38',
#  'ANZ_STATISTISCHE_HAUSHALTE_39',
#  'ANZ_STATISTISCHE_HAUSHALTE_4',
#  'ANZ_STATISTISCHE_HAUSHALTE_40',
#  'ANZ_STATISTISCHE_HAUSHALTE_41',
#  'ANZ_STATISTISCHE_HAUSHALTE_42',
#  'ANZ_STATISTISCHE_HAUSHALTE_43',
#  'ANZ_STATISTISCHE_HAUSHALTE_44',
#  'ANZ_STATISTISCHE_HAUSHALTE_45',
#  'ANZ_STATISTISCHE_HAUSHALTE_46',
#  'ANZ_STATISTISCHE_HAUSHALTE_47',
#  'ANZ_STATISTISCHE_HAUSHALTE_48',
#  'ANZ_STATISTISCHE_HAUSHALTE_49',
#  'ANZ_STATISTISCHE_HAUSHALTE_5',
#  'ANZ_STATISTISCHE_HAUSHALTE_50',
#  'ANZ_STATISTISCHE_HAUSHALTE_51',
#  'ANZ_STATISTISCHE_HAUSHALTE_52',
#  'ANZ_STATISTISCHE_HAUSHALTE_53',
#  'ANZ_STATISTISCHE_HAUSHALTE_54',
#  'ANZ_STATISTISCHE_HAUSHALTE_55',
#  'ANZ_STATISTISCHE_HAUSHALTE_56',
#  'ANZ_STATISTISCHE_HAUSHALTE_57',
#  'ANZ_STATISTISCHE_HAUSHALTE_58',
#  'ANZ_STATISTISCHE_HAUSHALTE_59',
#  'ANZ_STATISTISCHE_HAUSHALTE_6',
#  'ANZ_STATISTISCHE_HAUSHALTE_60',
#  'ANZ_STATISTISCHE_HAUSHALTE_61',
#  'ANZ_STATISTISCHE_HAUSHALTE_62',
#  'ANZ_STATISTISCHE_HAUSHALTE_63',
#  'ANZ_STATISTISCHE_HAUSHALTE_64',
#  'ANZ_STATISTISCHE_HAUSHALTE_65',
#  'ANZ_STATISTISCHE_HAUSHALTE_66',
#  'ANZ_STATISTISCHE_HAUSHALTE_67',
#  'ANZ_STATISTISCHE_HAUSHALTE_68',
#  'ANZ_STATISTISCHE_HAUSHALTE_69',
#  'ANZ_STATISTISCHE_HAUSHALTE_7',
#  'ANZ_STATISTISCHE_HAUSHALTE_70',
#  'ANZ_STATISTISCHE_HAUSHALTE_71',
#  'ANZ_STATISTISCHE_HAUSHALTE_72',
#  'ANZ_STATISTISCHE_HAUSHALTE_73',
#  'ANZ_STATISTISCHE_HAUSHALTE_74',
#  'ANZ_STATISTISCHE_HAUSHALTE_75',
#  'ANZ_STATISTISCHE_HAUSHALTE_76',
#  'ANZ_STATISTISCHE_HAUSHALTE_77',
#  'ANZ_STATISTISCHE_HAUSHALTE_78',
#  'ANZ_STATISTISCHE_HAUSHALTE_79',
#  'ANZ_STATISTISCHE_HAUSHALTE_8',
#  'ANZ_STATISTISCHE_HAUSHALTE_80',
#  'ANZ_STATISTISCHE_HAUSHALTE_81',
#  'ANZ_STATISTISCHE_HAUSHALTE_82',
#  'ANZ_STATISTISCHE_HAUSHALTE_83',
#  'ANZ_STATISTISCHE_HAUSHALTE_84',
#  'ANZ_STATISTISCHE_HAUSHALTE_85',
#  'ANZ_STATISTISCHE_HAUSHALTE_86',
#  'ANZ_STATISTISCHE_HAUSHALTE_87',
#  'ANZ_STATISTISCHE_HAUSHALTE_88',
#  'ANZ_STATISTISCHE_HAUSHALTE_89',
#  'ANZ_STATISTISCHE_HAUSHALTE_9',
#  'ANZ_STATISTISCHE_HAUSHALTE_90',
#  'ANZ_STATISTISCHE_HAUSHALTE_91',
#  'ANZ_STATISTISCHE_HAUSHALTE_92',
#  'ANZ_STATISTISCHE_HAUSHALTE_93',
#  'ANZ_STATISTISCHE_HAUSHALTE_94',
#  'ANZ_STATISTISCHE_HAUSHALTE_95',
#  'ANZ_STATISTISCHE_HAUSHALTE_96',
#  'ANZ_STATISTISCHE_HAUSHALTE_97',
#  'ANZ_STATISTISCHE_HAUSHALTE_98',
#  'ANZ_STATISTISCHE_HAUSHALTE_99',
#  'ANZ_STATISTISCHE_HAUSHALTE_nan',
#  'number of professional title holder in household _0',
#  'number of professional title holder in household _1',
#  'number of professional title holder in household _2',
#  'number of professional title holder in household _3',
#  'number of professional title holder in household _5',
#  'number of professional title holder in household _nan',
#  'ARBEIT_1',
#  'ARBEIT_2',
#  'ARBEIT_3',
#  'ARBEIT_4',
#  'ARBEIT_5',
#  'ARBEIT_9',
#  'ARBEIT_nan',
#  'distance to next urban centre _1',
#  'distance to next urban centre _2',
#  'distance to next urban centre _3',
#  'distance to next urban centre _4',
#  'distance to next urban centre _5',
#  'distance to next urban centre _6',
#  'distance to next urban centre _7',
#  'distance to next urban centre _nan',
#  'CAMEO classification 2015 - detailled classification_1A',
#  'CAMEO classification 2015 - detailled classification_1B',
#  'CAMEO classification 2015 - detailled classification_1C',
#  'CAMEO classification 2015 - detailled classification_1D',
#  'CAMEO classification 2015 - detailled classification_1E',
#  'CAMEO classification 2015 - detailled classification_2A',
#  'CAMEO classification 2015 - detailled classification_2B',
#  'CAMEO classification 2015 - detailled classification_2C',
#  'CAMEO classification 2015 - detailled classification_2D',
#  'CAMEO classification 2015 - detailled classification_3A',
#  'CAMEO classification 2015 - detailled classification_3B',
#  'CAMEO classification 2015 - detailled classification_3C',
#  'CAMEO classification 2015 - detailled classification_3D',
#  'CAMEO classification 2015 - detailled classification_4A',
#  'CAMEO classification 2015 - detailled classification_4B',
#  'CAMEO classification 2015 - detailled classification_4C',
#  'CAMEO classification 2015 - detailled classification_4D',
#  'CAMEO classification 2015 - detailled classification_4E',
#  'CAMEO classification 2015 - detailled classification_5A',
#  'CAMEO classification 2015 - detailled classification_5B',
#  'CAMEO classification 2015 - detailled classification_5C',
#  'CAMEO classification 2015 - detailled classification_5D',
#  'CAMEO classification 2015 - detailled classification_5E',
#  'CAMEO classification 2015 - detailled classification_5F',
#  'CAMEO classification 2015 - detailled classification_6A',
#  'CAMEO classification 2015 - detailled classification_6B',
#  'CAMEO classification 2015 - detailled classification_6C',
#  'CAMEO classification 2015 - detailled classification_6D',
#  'CAMEO classification 2015 - detailled classification_6E',
#  'CAMEO classification 2015 - detailled classification_6F',
#  'CAMEO classification 2015 - detailled classification_7A',
#  'CAMEO classification 2015 - detailled classification_7B',
#  'CAMEO classification 2015 - detailled classification_7C',
#  'CAMEO classification 2015 - detailled classification_7D',
#  'CAMEO classification 2015 - detailled classification_7E',
#  'CAMEO classification 2015 - detailled classification_8A',
#  'CAMEO classification 2015 - detailled classification_8B',
#  'CAMEO classification 2015 - detailled classification_8C',
#  'CAMEO classification 2015 - detailled classification_8D',
#  'CAMEO classification 2015 - detailled classification_9A',
#  'CAMEO classification 2015 - detailled classification_9B',
#  'CAMEO classification 2015 - detailled classification_9C',
#  'CAMEO classification 2015 - detailled classification_9D',
#  'CAMEO classification 2015 - detailled classification_9E',
#  'CAMEO classification 2015 - detailled classification_XX',
#  'CAMEO classification 2015 - detailled classification_nan',
#  'CAMEO classification 2015 - Uppergroup_1',
#  'CAMEO classification 2015 - Uppergroup_2',
#  'CAMEO classification 2015 - Uppergroup_3',
#  'CAMEO classification 2015 - Uppergroup_4',
#  'CAMEO classification 2015 - Uppergroup_5',
#  'CAMEO classification 2015 - Uppergroup_6',
#  'CAMEO classification 2015 - Uppergroup_7',
#  'CAMEO classification 2015 - Uppergroup_8',
#  'CAMEO classification 2015 - Uppergroup_9',
#  'CAMEO classification 2015 - Uppergroup_X',
#  'CAMEO classification 2015 - Uppergroup_nan',
#  'CAMEO_INTL_2015_12',
#  'CAMEO_INTL_2015_13',
#  'CAMEO_INTL_2015_14',
#  'CAMEO_INTL_2015_15',
#  'CAMEO_INTL_2015_22',
#  'CAMEO_INTL_2015_23',
#  'CAMEO_INTL_2015_24',
#  'CAMEO_INTL_2015_25',
#  'CAMEO_INTL_2015_31',
#  'CAMEO_INTL_2015_32',
#  'CAMEO_INTL_2015_33',
#  'CAMEO_INTL_2015_34',
#  'CAMEO_INTL_2015_35',
#  'CAMEO_INTL_2015_41',
#  'CAMEO_INTL_2015_43',
#  'CAMEO_INTL_2015_44',
#  'CAMEO_INTL_2015_45',
#  'CAMEO_INTL_2015_51',
#  'CAMEO_INTL_2015_52',
#  'CAMEO_INTL_2015_54',
#  'CAMEO_INTL_2015_55',
#  'CAMEO_INTL_2015_XX',
#  'CAMEO_INTL_2015_nan',
#  'customer journey typology_1',
#  'customer journey typology_2',
#  'customer journey typology_3',
#  'customer journey typology_4',
#  'customer journey typology_5',
#  'customer journey typology_6',
#  'customer journey typology_nan',
#  'CJT_KATALOGNUTZER_1',
#  'CJT_KATALOGNUTZER_2',
#  'CJT_KATALOGNUTZER_3',
#  'CJT_KATALOGNUTZER_4',
#  'CJT_KATALOGNUTZER_5',
#  'CJT_KATALOGNUTZER_nan',
#  'CJT_TYP_1_1',
#  'CJT_TYP_1_2',
#  'CJT_TYP_1_3',
#  'CJT_TYP_1_4',
#  'CJT_TYP_1_5',
#  'CJT_TYP_1_nan',
#  'CJT_TYP_2_1',
#  'CJT_TYP_2_2',
#  'CJT_TYP_2_3',
#  'CJT_TYP_2_4',
#  'CJT_TYP_2_5',
#  'CJT_TYP_2_nan',
#  'CJT_TYP_3_1',
#  'CJT_TYP_3_2',
#  'CJT_TYP_3_3',
#  'CJT_TYP_3_4',
#  'CJT_TYP_3_5',
#  'CJT_TYP_3_nan',
#  'CJT_TYP_4_1',
#  'CJT_TYP_4_2',
#  'CJT_TYP_4_3',
#  'CJT_TYP_4_4',
#  'CJT_TYP_4_5',
#  'CJT_TYP_4_nan',
#  'CJT_TYP_5_1',
#  'CJT_TYP_5_2',
#  'CJT_TYP_5_3',
#  'CJT_TYP_5_4',
#  'CJT_TYP_5_5',
#  'CJT_TYP_5_nan',
#  'CJT_TYP_6_1',
#  'CJT_TYP_6_2',
#  'CJT_TYP_6_3',
#  'CJT_TYP_6_4',
#  'CJT_TYP_6_5',
#  'CJT_TYP_6_nan',
#  'transaction activity BANKS in the last 12 months_0',
#  'transaction activity BANKS in the last 12 months_1',
#  'transaction activity BANKS in the last 12 months_2',
#  'transaction activity BANKS in the last 12 months_3',
#  'transaction activity BANKS in the last 12 months_4',
#  'transaction activity BANKS in the last 12 months_5',
#  'transaction activity BANKS in the last 12 months_6',
#  'transaction activity BANKS in the last 12 months_nan',
#  'transaction activity BANKS in the last 24 months_0',
#  'transaction activity BANKS in the last 24 months_1',
#  'transaction activity BANKS in the last 24 months_2',
#  'transaction activity BANKS in the last 24 months_3',
#  'transaction activity BANKS in the last 24 months_4',
#  'transaction activity BANKS in the last 24 months_5',
#  'transaction activity BANKS in the last 24 months_6',
#  'transaction activity BANKS in the last 24 months_nan',
#  'actuality of the last transaction for the segment banks TOTAL_1',
#  'actuality of the last transaction for the segment banks TOTAL_10',
#  'actuality of the last transaction for the segment banks TOTAL_2',
#  'actuality of the last transaction for the segment banks TOTAL_3',
#  'actuality of the last transaction for the segment banks TOTAL_4',
#  'actuality of the last transaction for the segment banks TOTAL_5',
#  'actuality of the last transaction for the segment banks TOTAL_6',
#  'actuality of the last transaction for the segment banks TOTAL_7',
#  'actuality of the last transaction for the segment banks TOTAL_8',
#  'actuality of the last transaction for the segment banks TOTAL_9',
#  'actuality of the last transaction for the segment banks TOTAL_nan',
#  'D19_BANKEN_DIREKT_0',
#  'D19_BANKEN_DIREKT_1',
#  'D19_BANKEN_DIREKT_2',
#  'D19_BANKEN_DIREKT_3',
#  'D19_BANKEN_DIREKT_4',
#  'D19_BANKEN_DIREKT_5',
#  'D19_BANKEN_DIREKT_6',
#  'D19_BANKEN_DIREKT_7',
#  'D19_BANKEN_DIREKT_nan',
#  'D19_BANKEN_GROSS_0',
#  'D19_BANKEN_GROSS_1',
#  'D19_BANKEN_GROSS_2',
#  'D19_BANKEN_GROSS_3',
#  'D19_BANKEN_GROSS_4',
#  'D19_BANKEN_GROSS_5',
#  'D19_BANKEN_GROSS_6',
#  'D19_BANKEN_GROSS_nan',
#  'D19_BANKEN_LOKAL_0',
#  'D19_BANKEN_LOKAL_1',
#  'D19_BANKEN_LOKAL_2',
#  'D19_BANKEN_LOKAL_3',
#  'D19_BANKEN_LOKAL_4',
#  'D19_BANKEN_LOKAL_5',
#  'D19_BANKEN_LOKAL_6',
#  'D19_BANKEN_LOKAL_7',
#  'D19_BANKEN_LOKAL_nan',
#  'actuality of the last transaction for the segment banks OFFLINE_1',
#  'actuality of the last transaction for the segment banks OFFLINE_10',
#  'actuality of the last transaction for the segment banks OFFLINE_2',
#  'actuality of the last transaction for the segment banks OFFLINE_3',
#  'actuality of the last transaction for the segment banks OFFLINE_4',
#  'actuality of the last transaction for the segment banks OFFLINE_5',
#  'actuality of the last transaction for the segment banks OFFLINE_6',
#  'actuality of the last transaction for the segment banks OFFLINE_7',
#  'actuality of the last transaction for the segment banks OFFLINE_8',
#  'actuality of the last transaction for the segment banks OFFLINE_9',
#  'actuality of the last transaction for the segment banks OFFLINE_nan',
#  'actuality of the last transaction for the segment banks ONLINE_1',
#  'actuality of the last transaction for the segment banks ONLINE_10',
#  'actuality of the last transaction for the segment banks ONLINE_2',
#  'actuality of the last transaction for the segment banks ONLINE_3',
#  'actuality of the last transaction for the segment banks ONLINE_4',
#  'actuality of the last transaction for the segment banks ONLINE_5',
#  'actuality of the last transaction for the segment banks ONLINE_6',
#  'actuality of the last transaction for the segment banks ONLINE_7',
#  'actuality of the last transaction for the segment banks ONLINE_8',
#  'actuality of the last transaction for the segment banks ONLINE_9',
#  'actuality of the last transaction for the segment banks ONLINE_nan',
#  'amount of online transactions within all transactions in the segment bank _0',
#  'amount of online transactions within all transactions in the segment bank _10',
#  'amount of online transactions within all transactions in the segment bank _2',
#  'amount of online transactions within all transactions in the segment bank _3',
#  'amount of online transactions within all transactions in the segment bank _4',
#  'amount of online transactions within all transactions in the segment bank _5',
#  'amount of online transactions within all transactions in the segment bank _6',
#  'amount of online transactions within all transactions in the segment bank _7',
#  'amount of online transactions within all transactions in the segment bank _8',
#  'amount of online transactions within all transactions in the segment bank _9',
#  'amount of online transactions within all transactions in the segment bank _nan',
#  'D19_BANKEN_REST_0',
#  'D19_BANKEN_REST_1',
#  'D19_BANKEN_REST_2',
#  'D19_BANKEN_REST_3',
#  'D19_BANKEN_REST_4',
#  'D19_BANKEN_REST_5',
#  'D19_BANKEN_REST_6',
#  'D19_BANKEN_REST_7',
#  'D19_BANKEN_REST_nan',
#  'D19_BEKLEIDUNG_GEH_0',
#  'D19_BEKLEIDUNG_GEH_1',
#  'D19_BEKLEIDUNG_GEH_2',
#  'D19_BEKLEIDUNG_GEH_3',
#  'D19_BEKLEIDUNG_GEH_4',
#  'D19_BEKLEIDUNG_GEH_5',
#  'D19_BEKLEIDUNG_GEH_6',
#  'D19_BEKLEIDUNG_GEH_7',
#  'D19_BEKLEIDUNG_GEH_nan',
#  'D19_BEKLEIDUNG_REST_0',
#  'D19_BEKLEIDUNG_REST_1',
#  'D19_BEKLEIDUNG_REST_2',
#  'D19_BEKLEIDUNG_REST_3',
#  'D19_BEKLEIDUNG_REST_4',
#  'D19_BEKLEIDUNG_REST_5',
#  'D19_BEKLEIDUNG_REST_6',
#  'D19_BEKLEIDUNG_REST_7',
#  'D19_BEKLEIDUNG_REST_nan',
#  'D19_BILDUNG_0',
#  'D19_BILDUNG_1',
#  'D19_BILDUNG_2',
#  'D19_BILDUNG_3',
#  'D19_BILDUNG_4',
#  'D19_BILDUNG_5',
#  'D19_BILDUNG_6',
#  'D19_BILDUNG_7',
#  'D19_BILDUNG_nan',
#  'D19_BIO_OEKO_0',
#  'D19_BIO_OEKO_1',
#  'D19_BIO_OEKO_2',
#  'D19_BIO_OEKO_3',
#  'D19_BIO_OEKO_4',
#  'D19_BIO_OEKO_5',
#  'D19_BIO_OEKO_6',
#  'D19_BIO_OEKO_7',
#  'D19_BIO_OEKO_nan',
#  'D19_BUCH_CD_0',
#  'D19_BUCH_CD_1',
#  'D19_BUCH_CD_2',
#  'D19_BUCH_CD_3',
#  'D19_BUCH_CD_4',
#  'D19_BUCH_CD_5',
#  'D19_BUCH_CD_6',
#  'D19_BUCH_CD_7',
#  'D19_BUCH_CD_nan',
#  'D19_DIGIT_SERV_0',
#  'D19_DIGIT_SERV_1',
#  'D19_DIGIT_SERV_2',
#  'D19_DIGIT_SERV_3',
#  'D19_DIGIT_SERV_4',
#  'D19_DIGIT_SERV_5',
#  'D19_DIGIT_SERV_6',
#  'D19_DIGIT_SERV_7',
#  'D19_DIGIT_SERV_nan',
#  'D19_DROGERIEARTIKEL_0',
#  'D19_DROGERIEARTIKEL_1',
#  'D19_DROGERIEARTIKEL_2',
#  'D19_DROGERIEARTIKEL_3',
#  'D19_DROGERIEARTIKEL_4',
#  'D19_DROGERIEARTIKEL_5',
#  'D19_DROGERIEARTIKEL_6',
#  'D19_DROGERIEARTIKEL_7',
#  'D19_DROGERIEARTIKEL_nan',
#  'D19_ENERGIE_0',
#  'D19_ENERGIE_1',
#  'D19_ENERGIE_2',
#  'D19_ENERGIE_3',
#  'D19_ENERGIE_4',
#  'D19_ENERGIE_5',
#  'D19_ENERGIE_6',
#  'D19_ENERGIE_7',
#  'D19_ENERGIE_nan',
#  'D19_FREIZEIT_0',
#  'D19_FREIZEIT_1',
#  'D19_FREIZEIT_2',
#  'D19_FREIZEIT_3',
#  'D19_FREIZEIT_4',
#  'D19_FREIZEIT_5',
#  'D19_FREIZEIT_6',
#  'D19_FREIZEIT_7',
#  'D19_FREIZEIT_nan',
#  'D19_GARTEN_0',
#  'D19_GARTEN_1',
#  'D19_GARTEN_2',
#  'D19_GARTEN_3',
#  'D19_GARTEN_4',
#  'D19_GARTEN_5',
#  'D19_GARTEN_6',
#  'D19_GARTEN_7',
#  'D19_GARTEN_nan',
#  'transaction activity TOTAL POOL in the last 12 months _0',
#  'transaction activity TOTAL POOL in the last 12 months _1',
#  'transaction activity TOTAL POOL in the last 12 months _2',
#  'transaction activity TOTAL POOL in the last 12 months _3',
#  'transaction activity TOTAL POOL in the last 12 months _4',
#  'transaction activity TOTAL POOL in the last 12 months _5',
#  'transaction activity TOTAL POOL in the last 12 months _6',
#  'transaction activity TOTAL POOL in the last 12 months _nan',
#  'transaction activity TOTAL POOL in the last 24 months _0',
#  'transaction activity TOTAL POOL in the last 24 months _1',
#  'transaction activity TOTAL POOL in the last 24 months _2',
#  'transaction activity TOTAL POOL in the last 24 months _3',
#  'transaction activity TOTAL POOL in the last 24 months _4',
#  'transaction activity TOTAL POOL in the last 24 months _5',
#  'transaction activity TOTAL POOL in the last 24 months _6',
#  'transaction activity TOTAL POOL in the last 24 months _nan',
#  'actuality of the last transaction with the complete file TOTAL_1',
#  'actuality of the last transaction with the complete file TOTAL_10',
#  'actuality of the last transaction with the complete file TOTAL_2',
#  'actuality of the last transaction with the complete file TOTAL_3',
#  'actuality of the last transaction with the complete file TOTAL_4',
#  'actuality of the last transaction with the complete file TOTAL_5',
#  'actuality of the last transaction with the complete file TOTAL_6',
#  'actuality of the last transaction with the complete file TOTAL_7',
#  'actuality of the last transaction with the complete file TOTAL_8',
#  'actuality of the last transaction with the complete file TOTAL_9',
#  'actuality of the last transaction with the complete file TOTAL_nan',
#  'actuality of the last transaction with the complete file OFFLINE_1',
#  'actuality of the last transaction with the complete file OFFLINE_10',
#  'actuality of the last transaction with the complete file OFFLINE_2',
#  'actuality of the last transaction with the complete file OFFLINE_3',
#  'actuality of the last transaction with the complete file OFFLINE_4',
#  'actuality of the last transaction with the complete file OFFLINE_5',
#  'actuality of the last transaction with the complete file OFFLINE_6',
#  'actuality of the last transaction with the complete file OFFLINE_7',
#  'actuality of the last transaction with the complete file OFFLINE_8',
#  'actuality of the last transaction with the complete file OFFLINE_9',
#  'actuality of the last transaction with the complete file OFFLINE_nan',
#  'actuality of the last transaction with the complete file ONLINE_1',
#  'actuality of the last transaction with the complete file ONLINE_10',
#  'actuality of the last transaction with the complete file ONLINE_2',
#  'actuality of the last transaction with the complete file ONLINE_3',
#  'actuality of the last transaction with the complete file ONLINE_4',
#  'actuality of the last transaction with the complete file ONLINE_5',
#  'actuality of the last transaction with the complete file ONLINE_6',
#  'actuality of the last transaction with the complete file ONLINE_7',
#  'actuality of the last transaction with the complete file ONLINE_8',
#  'actuality of the last transaction with the complete file ONLINE_9',
#  'actuality of the last transaction with the complete file ONLINE_nan',
#  'amount of online transactions within all transactions in the complete file _0',
#  'amount of online transactions within all transactions in the complete file _1',
#  'amount of online transactions within all transactions in the complete file _10',
#  'amount of online transactions within all transactions in the complete file _2',
#  'amount of online transactions within all transactions in the complete file _3',
#  'amount of online transactions within all transactions in the complete file _4',
#  'amount of online transactions within all transactions in the complete file _5',
#  'amount of online transactions within all transactions in the complete file _6',
#  ...]

# %%
len(list(customers_clean.columns))
# Out:
# 7749

# %%
azdias_clean = pd.get_dummies(azdias_clean.iloc[:, 1:], dummy_na=True)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-86-3a41cee33c90> in <module>()
# ----> 1 azdias_clean_1 = pd.get_dummies(azdias_clean.iloc[:, 1:], dummy_na=True)
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/reshape/reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     890             dummy = _get_dummies_1d(col[1], prefix=pre, prefix_sep=sep,
#     891                                     dummy_na=dummy_na, sparse=sparse,
# --> 892                                     drop_first=drop_first, dtype=dtype)
#     893             with_dummies.append(dummy)
#     894         result = concat(with_dummies, axis=1)
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/reshape/reshape.py in _get_dummies_1d(data, prefix, prefix_sep, dummy_na, sparse, drop_first, dtype)
#     978
#     979     else:
# --> 980         dummy_mat = np.eye(number_of_cols, dtype=dtype).take(codes, axis=0)
#     981
#     982         if not dummy_na:
#
# MemoryError:

# %%
len(list(azdias_clean.columns))

# %%
list(azdias_clean.columns)

# %% [markdown]
# ## Part 1: Customer Segmentation Report
#
# The main bulk of your analysis will come in this part of the project. Here, you should use unsupervised learning techniques to describe the relationship between the demographics of the company's existing customers and the general population of Germany. By the end of this part, you should be able to describe parts of the general population that are more likely to be part of the mail-order company's main customer base, and which parts of the general population are less so.

# %% [markdown]
# ## Part 2: Supervised Learning Model
#
# Now that you've found which parts of the population are more likely to be customers of the mail-order company, it's time to build a prediction model. Each of the rows in the "MAILOUT" data files represents an individual that was targeted for a mailout campaign. Ideally, we should be able to use the demographic information from each individual to decide whether or not it will be worth it to include that person in the campaign.
#
# The "MAILOUT" data has been split into two approximately equal parts, each with almost 43 000 data rows. In this part, you can verify your model with the "TRAIN" partition, which includes a column, "RESPONSE", that states whether or not a person became a customer of the company following the campaign. In the next part, you'll need to create predictions on the "TEST" partition, where the "RESPONSE" column has been withheld.

# %%
mailout_train = pd.read_csv('../../data/Term2/capstone/arvato_data/Udacity_MAILOUT_052018_TRAIN.csv', sep=';')

# %% [markdown]
# ## Part 3: Kaggle Competition
#
# Now that you've created a model to predict which individuals are most likely to respond to a mailout campaign, it's time to test that model in competition through Kaggle. If you click on the link [here](http://www.kaggle.com/t/21e6d45d4c574c7fa2d868f0e8c83140), you'll be taken to the competition page where, if you have a Kaggle account, you can enter. If you're one of the top performers, you may have the chance to be contacted by a hiring manager from Arvato or Bertelsmann for an interview!
#
# Your entry to the competition should be a CSV file with two columns. The first column should be a copy of "LNR", which acts as an ID number for each individual in the "TEST" partition. The second column, "RESPONSE", should be some measure of how likely each individual became a customer – this might not be a straightforward probability. As you should have found in Part 2, there is a large output class imbalance, where most individuals did not respond to the mailout. Thus, predicting individual classes and using accuracy does not seem to be an appropriate performance evaluation method. Instead, the competition will be using AUC to evaluate performance. The exact values of the "RESPONSE" column do not matter as much: only that the higher values try to capture as many of the actual customers as possible, early in the ROC curve sweep.

# %%
mailout_test = pd.read_csv('../../data/Term2/capstone/arvato_data/Udacity_MAILOUT_052018_TEST.csv', sep=';')
